# %% [markdown]
# ![example](images/director_shot.jpeg)

# %% [markdown]
# # Project Title
#
# **Authors:** Student 1, Student 2, Student 3
# ***

# %% [markdown]
# ## Overview
#
# A one-paragraph overview of the project, including the business problem, data, methods, results and recommendations.

# %% [markdown]
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# ***
# Questions to consider:
# * What are the business's pain points related to this project?
# * How did you pick the data analysis question(s) that you did?
# * Why are these questions important from a business perspective?
# ***

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
# ***
# Questions to consider:
# * Where did the data come from, and how do they relate to the data analysis questions?
# * What do the data represent? Who is in the sample and what variables are included?
# * What is the target variable?
# * What are the properties of the variables you intend to use?
# ***

# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Here you run your code to explore the data

# %%
df = pd.read_csv('data/Video_Games.csv', names=['asin', 'user', 'rating', 'timestamp'])
df
# Out:
#                asin            user  rating   timestamp
# 0        0439381673  A21ROB4YDOZA5P     1.0  1402272000
# 1        0439381673  A3TNZ2Q5E7HTHD     3.0  1399680000
# 2        0439381673  A1OKRM3QFEATQO     4.0  1391731200
# 3        0439381673  A2XO1JFCNEYV3T     1.0  1391731200
# 4        0439381673  A19WLPIRHD15TH     4.0  1389830400
# ...             ...             ...     ...         ...
# 2565344  B01HJEBIAA   ANGB54K3888S4     5.0  1533081600
# 2565345  B01HJEBIAA  A3TEVKR0ZVQB2T     5.0  1531785600
# 2565346  B01HJEBIAA   ABE7YPWEHNVJZ     5.0  1530835200
# 2565347  B01HJEBIAA  A3ES9QBK3G192O     5.0  1528761600
# 2565348  B01HJEBIAA  A194UPGR3OXZB7     5.0  1524096000
#
# [2565349 rows x 4 columns]

# %%
asin_list = df['asin'].unique()

# %%
np.arange(len(asin_list))
# Out:
# array([    0,     1,     2, ..., 71979, 71980, 71981])

# %%
asin_lookup = dict(zip(np.arange(len(asin_list)), asin_list))

# %%
asin_map = dict(zip(asin_list, np.arange(len(asin_list))))

# %%
asin_map
# Out:
# {'0439381673': 0,
#  '0700026657': 1,
#  '0700099867': 2,
#  '0700026398': 3,
#  '0758534531': 4,
#  '0804161380': 5,
#  '1616616873': 6,
#  '3815864844': 7,
#  '3828770193': 8,
#  '3866811659': 9,
#  '6050036071': 10,
#  '7293000960': 11,
#  '7293000936': 12,
#  '7543450933': 13,
#  '7544256944': 14,
#  '7561321074': 15,
#  '8176503290': 16,
#  '8565000168': 17,
#  '907843905X': 18,
#  '952590444X': 19,
#  '9625990674': 20,
#  '9625990992': 21,
#  '9629551462': 22,
#  '9629971372': 23,
#  '9752300480': 24,
#  '9758648950': 25,
#  '9756663855': 26,
#  '975539463X': 27,
#  '9867299434': 28,
#  '988800171X': 29,
#  '9882155456': 30,
#  '9882106463': 31,
#  'B000003SQQ': 32,
#  'B000006OTB': 33,
#  'B000006OWS': 34,
#  'B000006OVF': 35,
#  'B000006OVJ': 36,
#  'B000006OWT': 37,
#  'B000006OVG': 38,
#  'B000006P0M': 39,
#  'B000006P0J': 40,
#  'B000006OVE': 41,
#  'B000006P0K': 42,
#  'B000006OVK': 43,
#  'B000006OWR': 44,
#  'B000006OVL': 45,
#  'B000006RGS': 46,
#  'B000006P0P': 47,
#  'B000006RGQ': 48,
#  'B000006RGO': 49,
#  'B000006RGR': 50,
#  'B000006RGP': 51,
#  'B000006OVI': 52,
#  'B000007NJC': 53,
#  'B000009QCX': 54,
#  'B000009QCW': 55,
#  'B000009QD0': 56,
#  'B000009QCV': 57,
#  'B000009QD1': 58,
#  'B00000DMAN': 59,
#  'B00000DMB6': 60,
#  'B00000DMB2': 61,
#  'B00000DMAM': 62,
#  'B00000DMAT': 63,
#  'B00000DMAO': 64,
#  'B00000DMB7': 65,
#  'B00000DMAA': 66,
#  'B00000DMAH': 67,
#  'B00000DMB3': 68,
#  'B00000DMAD': 69,
#  'B00000DMAQ': 70,
#  'B00000DMB4': 71,
#  'B00000DMAX': 72,
#  'B00000DMA8': 73,
#  'B00000DMB5': 74,
#  'B00000DMAP': 75,
#  'B00000DMAZ': 76,
#  'B00000DMAE': 77,
#  'B00000DMAR': 78,
#  'B00000DMB9': 79,
#  'B00000DMAV': 80,
#  'B00000F1GM': 81,
#  'B00000F1GK': 82,
#  'B00000F1GS': 83,
#  'B00000F1GI': 84,
#  'B00000G16I': 85,
#  'B00000G2OP': 86,
#  'B00000I1BE': 87,
#  'B00000I1BT': 88,
#  'B00000I1BV': 89,
#  'B00000I1BN': 90,
#  'B00000I1BB': 91,
#  'B00000I1BK': 92,
#  'B00000I1BZ': 93,
#  'B00000I1BU': 94,
#  'B00000I1BA': 95,
#  'B00000I1C0': 96,
#  'B00000I1C2': 97,
#  'B00000I1BY': 98,
#  'B00000I1C3': 99,
#  'B00000I1C1': 100,
#  'B00000I1BG': 101,
#  'B00000I1BX': 102,
#  'B00000I1BR': 103,
#  'B00000I1B8': 104,
#  'B00000I1BQ': 105,
#  'B00000I1BF': 106,
#  'B00000I1BS': 107,
#  'B00000I1BP': 108,
#  'B00000I1BJ': 109,
#  'B00000ID61': 110,
#  'B00000IFRI': 111,
#  'B00000IFKW': 112,
#  'B00000ID60': 113,
#  'B00000IG7T': 114,
#  'B00000IFRG': 115,
#  'B00000IKCG': 116,
#  'B00000IKQH': 117,
#  'B00000IKCC': 118,
#  'B00000IJVY': 119,
#  'B00000IMK5': 120,
#  'B00000IGZM': 121,
#  'B00000IMNB': 122,
#  'B00000IODY': 123,
#  'B00000INR2': 124,
#  'B00000IPEE': 125,
#  'B00000IPDS': 126,
#  'B00000IWYR': 127,
#  'B00000IXB8': 128,
#  'B00000IWIW': 129,
#  'B00000IZ7Q': 130,
#  'B00000IZS1': 131,
#  'B00000IZ8A': 132,
#  'B00000IYEQ': 133,
#  'B00000J2OO': 134,
#  'B00000J2W7': 135,
#  'B00000J98X': 136,
#  'B00000J97G': 137,
#  'B00000J9J9': 138,
#  'B00000J96V': 139,
#  'B00000J9JI': 140,
#  'B00000JBL1': 141,
#  'B00000JD79': 142,
#  'B00000JDFT': 143,
#  'B00000JFC6': 144,
#  'B00000JDDY': 145,
#  'B00000JHPD': 146,
#  'B00000JHPN': 147,
#  'B00000JDJ2': 148,
#  'B00000JIUG': 149,
#  'B00000JHPT': 150,
#  'B00000JGAR': 151,
#  'B00000JL60': 152,
#  'B00000JLPC': 153,
#  'B00000JLAE': 154,
#  'B00000JMWB': 155,
#  'B00000JL6V': 156,
#  'B00000JNHJ': 157,
#  'B00000JQ0V': 158,
#  'B00000JQQH': 159,
#  'B00000JQQJ': 160,
#  'B00000JQQM': 161,
#  'B00000JRT2': 162,
#  'B00000JRSB': 163,
#  'B00000JWGM': 164,
#  'B00000JWGO': 165,
#  'B00000K11D': 166,
#  'B00000K0DJ': 167,
#  'B00000K115': 168,
#  'B00000K125': 169,
#  'B00000K117': 170,
#  'B00000K11O': 171,
#  'B00000K10O': 172,
#  'B00000K1V9': 173,
#  'B00000K1XN': 174,
#  'B00000K10U': 175,
#  'B00000K1V7': 176,
#  'B00000K1XU': 177,
#  'B00000K1XJ': 178,
#  'B00000K1XF': 179,
#  'B00000K2GB': 180,
#  'B00000K2G7': 181,
#  'B00000K1VK': 182,
#  'B00000K1V2': 183,
#  'B00000K2G9': 184,
#  'B00000K1VE': 185,
#  'B00000K2R4': 186,
#  'B00000K2RA': 187,
#  'B00000K2GJ': 188,
#  'B00000K2R7': 189,
#  'B00000K1X1': 190,
#  'B00000K1VA': 191,
#  'B00000K2R6': 192,
#  'B00000K2R8': 193,
#  'B00000K2Y6': 194,
#  'B00000K2X5': 195,
#  'B00000K2GI': 196,
#  'B00000K3DK': 197,
#  'B00000K3Q2': 198,
#  'B00000K39I': 199,
#  'B00000K3XB': 200,
#  'B00000K2R9': 201,
#  'B00000K3X9': 202,
#  'B00000K2XJ': 203,
#  'B00000K3Y2': 204,
#  'B00000K2YD': 205,
#  'B00000K13K': 206,
#  'B00000K1VC': 207,
#  'B00000K3DM': 208,
#  'B00000K4BX': 209,
#  'B00000K4DW': 210,
#  'B00000K4EC': 211,
#  'B00000K4CR': 212,
#  'B00000K4C0': 213,
#  'B00000K4C9': 214,
#  'B00000K4AX': 215,
#  'B00000K1VG': 216,
#  'B00000K4C7': 217,
#  'B00000K4DV': 218,
#  'B00000K4CC': 219,
#  'B00000K4CX': 220,
#  'B00000K1AF': 221,
#  'B00000K4E1': 222,
#  'B00000K4KC': 223,
#  'B00000K2R5': 224,
#  'B00000K4DK': 225,
#  'B00000K50S': 226,
#  'B00000K4CZ': 227,
#  'B00000K51C': 228,
#  'B00000K57N': 229,
#  'B00000K518': 230,
#  'B00000K58S': 231,
#  'B00000K4LL': 232,
#  'B00000K4D4': 233,
#  'B00000K4KM': 234,
#  'B00000K514': 235,
#  'B00000K4M6': 236,
#  'B00000K4D2': 237,
#  'B00000K4DE': 238,
#  'B00000K57S': 239,
#  'B00000K4BU': 240,
#  'B00000K4TQ': 241,
#  'B00000K4ST': 242,
#  'B00000K599': 243,
#  'B00000K594': 244,
#  'B00000K4YJ': 245,
#  'B00000K4TP': 246,
#  'B00000SWOY': 247,
#  'B00001IVB4': 248,
#  'B00000SZZV': 249,
#  'B00001IVB6': 250,
#  'B00000K4MC': 251,
#  'B00001IVCC': 252,
#  'B00000K4D0': 253,
#  'B00001IVGE': 254,
#  'B00000T94P': 255,
#  'B00000K4YH': 256,
#  'B00001KUII': 257,
#  'B00001L2BT': 258,
#  'B00001IVR8': 259,
#  'B00000K57P': 260,
#  'B00000K4TX': 261,
#  'B00001LDC2': 262,
#  'B00001LDC1': 263,
#  'B00001IVUO': 264,
#  'B00001IVU8': 265,
#  'B00001LDBZ': 266,
#  'B00001IVRD': 267,
#  'B00001LDCD': 268,
#  'B00001LDC7': 269,
#  'B00001LCDB': 270,
#  'B00001LCDH': 271,
#  'B00001N2MT': 272,
#  'B00001LAE2': 273,
#  'B00001LCDO': 274,
#  'B00001LCDD': 275,
#  'B00001LDCK': 276,
#  'B00001N2P5': 277,
#  'B00001IVLY': 278,
#  'B00001LDCC': 279,
#  'B00001LCDP': 280,
#  'B00000K50Z': 281,
#  'B00001LDC8': 282,
#  'B00001IVUC': 283,
#  'B00000K5D8': 284,
#  'B00001IVUB': 285,
#  'B00000K4LI': 286,
#  'B00001NFRQ': 287,
#  'B00001NFSY': 288,
#  'B00001LDBR': 289,
#  'B00001LDC5': 290,
#  'B00001LDBU': 291,
#  'B00001LCDF': 292,
#  'B00001LCDK': 293,
#  'B00001LCDM': 294,
#  'B00000PLUW': 295,
#  'B00000K4KO': 296,
#  'B00001NFS5': 297,
#  'B00001LCD9': 298,
#  'B00001NFUA': 299,
#  'B00001NTSN': 300,
#  'B00001LDBT': 301,
#  'B00001N2M9': 302,
#  'B00001IVR9': 303,
#  'B00001N2OU': 304,
#  'B00001NFVI': 305,
#  'B00001LC25': 306,
#  'B00001NTSO': 307,
#  'B00001NTSG': 308,
#  'B00001OHDA': 309,
#  'B00001IVB8': 310,
#  'B00001OWYX': 311,
#  'B00001NFRB': 312,
#  'B00001N2OM': 313,
#  'B00001OPJD': 314,
#  'B00001P4QN': 315,
#  'B00001OWYL': 316,
#  'B00001OHC1': 317,
#  'B00000K3QV': 318,
#  'B00001OX4T': 319,
#  'B00001LDBY': 320,
#  'B00001P4Y9': 321,
#  'B00001P4Y6': 322,
#  'B00001OWYQ': 323,
#  'B00001QED2': 324,
#  'B00001OX4H': 325,
#  'B00001QEEC': 326,
#  'B00001QECO': 327,
#  'B00001QECX': 328,
#  'B00001QEPC': 329,
#  'B00001QEP6': 330,
#  'B00001QED5': 331,
#  'B00001QEQ9': 332,
#  'B00001QES0': 333,
#  'B00001QEP9': 334,
#  'B00001QEQ8': 335,
#  'B00001OWYK': 336,
#  'B00001QER9': 337,
#  'B00001OPJB': 338,
#  'B00001QEPQ': 339,
#  'B00001QER3': 340,
#  'B00001OX4W': 341,
#  'B00001QEP7': 342,
#  'B00001QHY6': 343,
#  'B00001QHW9': 344,
#  'B00001QHXS': 345,
#  'B00001QERF': 346,
#  'B00000TBQQ': 347,
#  'B00001QERY': 348,
#  'B00001QHXM': 349,
#  'B00001QHXE': 350,
#  'B00001QHWM': 351,
#  'B00001QHWT': 352,
#  'B00001QHY4': 353,
#  'B00001QEQA': 354,
#  'B00001OWYW': 355,
#  'B00001QEQZ': 356,
#  'B00001QHXZ': 357,
#  'B00001R3XK': 358,
#  'B00001SHNN': 359,
#  'B00001QHYE': 360,
#  'B00001OWYN': 361,
#  'B00001R3XA': 362,
#  'B00001QEQL': 363,
#  'B00001QERU': 364,
#  'B00001SHNG': 365,
#  'B00001QERI': 366,
#  'B00001SHON': 367,
#  'B00001SVE2': 368,
#  'B00001T37S': 369,
#  'B00001QECQ': 370,
#  'B00001SVI8': 371,
#  'B00001SVI9': 372,
#  'B00001TZYA': 373,
#  'B00001TZYF': 374,
#  'B00001TZYD': 375,
#  'B00001TZYB': 376,
#  'B00001W0E6': 377,
#  'B00001WQI5': 378,
#  'B00001WQIT': 379,
#  'B00001W0J2': 380,
#  'B00001WQHU': 381,
#  'B00001WQHN': 382,
#  'B00001WQIS': 383,
#  'B00001WQIP': 384,
#  'B00001X510': 385,
#  'B00001WQHQ': 386,
#  'B00001X50L': 387,
#  'B00001WRJO': 388,
#  'B00001WQHT': 389,
#  'B00001X4Z3': 390,
#  'B00001WRT0': 391,
#  'B00001WQHO': 392,
#  'B00001WRSO': 393,
#  'B00001QEPV': 394,
#  'B00001WRSN': 395,
#  'B00001WRT2': 396,
#  'B00001W0J6': 397,
#  'B00001XDK9': 398,
#  'B00001X5CG': 399,
#  'B00001X5CE': 400,
#  'B00001XDK5': 401,
#  'B00001XDKC': 402,
#  'B00001X50Y': 403,
#  'B00001X5C3': 404,
#  'B00001X50U': 405,
#  'B00001WQIR': 406,
#  'B00001XDU6': 407,
#  'B00001WRJM': 408,
#  'B00001WQHX': 409,
#  'B00001XDVT': 410,
#  'B00001XDTK': 411,
#  'B00001YVBH': 412,
#  'B00001WRJ1': 413,
#  'B00001YVBN': 414,
#  'B00001XDKD': 415,
#  'B00001XDKL': 416,
#  'B00001XDTT': 417,
#  'B00001XDUB': 418,
#  'B00001YVHR': 419,
#  'B00001XDKO': 420,
#  'B00001X4Z4': 421,
#  'B00001YVBL': 422,
#  'B00001ZT3S': 423,
#  'B00001YVFK': 424,
#  'B00001ZT77': 425,
#  'B00001ZT7T': 426,
#  'B00001X5BU': 427,
#  'B00001XDJZ': 428,
#  'B00001XDTY': 429,
#  'B00001XDKF': 430,
#  'B00001XDTU': 431,
#  'B00001ZT3X': 432,
#  'B00001X50M': 433,
#  'B00001ZT53': 434,
#  'B00001ZT47': 435,
#  'B00001SVE6': 436,
#  'B00001ZT4A': 437,
#  'B00001XDVZ': 438,
#  'B00001ZULK': 439,
#  'B00001ZT9E': 440,
#  'B00001ZUMM': 441,
#  'B00001ZUGO': 442,
#  'B00001WRSK': 443,
#  'B00001YVIB': 444,
#  'B00001ZWOY': 445,
#  'B00001ZUOQ': 446,
#  'B00001ZUGT': 447,
#  'B00001ZULP': 448,
#  'B00001ZWP8': 449,
#  'B00001ZULE': 450,
#  'B00001ZT50': 451,
#  'B00001ZWPM': 452,
#  'B00001ZWOP': 453,
#  'B00001ZWWT': 454,
#  'B00001ZWXH': 455,
#  'B00001ZUHJ': 456,
#  'B00001ZULZ': 457,
#  'B00001ZUW8': 458,
#  'B00001ZWUQ': 459,
#  'B00001ZUL7': 460,
#  'B00001ZUHU': 461,
#  'B00001ZWPX': 462,
#  'B00001ZWVK': 463,
#  'B00001X5C1': 464,
#  'B00001ZWVR': 465,
#  'B00001ZWNA': 466,
#  'B00001ZUOD': 467,
#  'B00001ZWQI': 468,
#  'B0000205WV': 469,
#  'B00001ZUOY': 470,
#  'B00001ZUMH': 471,
#  'B000021XYT': 472,
#  'B000021Y2F': 473,
#  'B000021Y4A': 474,
#  'B000021Y5S': 475,
#  'B000021Y30': 476,
#  'B000021Y4G': 477,
#  'B000021Y4W': 478,
#  'B000021XYX': 479,
#  'B000021Y5J': 480,
#  'B000021Y5P': 481,
#  'B000021Y5R': 482,
#  'B000021Y5F': 483,
#  'B000021Y56': 484,
#  'B000021Y5Q': 485,
#  'B000021Y3D': 486,
#  'B000021Y4U': 487,
#  'B00001ZWMV': 488,
#  'B000021Y32': 489,
#  'B000021YUG': 490,
#  'B000021Y2Z': 491,
#  'B000021Y5T': 492,
#  'B000021YUI': 493,
#  'B000021Y2Y': 494,
#  'B000021Y1K': 495,
#  'B0000206H5': 496,
#  'B000021Y1B': 497,
#  'B000021Y5U': 498,
#  'B000021Y5V': 499,
#  'B000021YUM': 500,
#  'B000021XYY': 501,
#  'B000023VUP': 502,
#  'B000023MCN': 503,
#  'B000023MCR': 504,
#  'B000023MD4': 505,
#  'B000023VTY': 506,
#  'B000028U28': 507,
#  'B000028U2E': 508,
#  'B0000296NT': 509,
#  'B000028U27': 510,
#  'B000028U21': 511,
#  'B000028U2F': 512,
#  'B0000296O5': 513,
#  'B0000296ZJ': 514,
#  'B0000296ZD': 515,
#  'B00002971H': 516,
#  'B0000296ZB': 517,
#  'B00002970G': 518,
#  'B000028U20': 519,
#  'B0000296ZF': 520,
#  'B00002AH2T': 521,
#  'B00002CF98': 522,
#  'B00002CF9G': 523,
#  'B0000296ZP': 524,
#  'B0000296Z1': 525,
#  'B00002CF5W': 526,
#  'B00002AH2U': 527,
#  'B000028U2D': 528,
#  'B00002CF8V': 529,
#  'B00002CF81': 530,
#  'B00002CF94': 531,
#  'B00002CF9M': 532,
#  'B00002CFA0': 533,
#  'B00002CETT': 534,
#  'B00002971O': 535,
#  'B0000296ZN': 536,
#  'B00002CF8Q': 537,
#  'B00002970R': 538,
#  'B00002CF96': 539,
#  'B00002970H': 540,
#  'B00002DHEU': 541,
#  'B0000296ZA': 542,
#  'B00002CF99': 543,
#  'B00002CF8U': 544,
#  'B00002EIZN': 545,
#  'B00002EPGW': 546,
#  'B000029706': 547,
#  'B00002DHER': 548,
#  'B00002EIX4': 549,
#  'B00002EIZW': 550,
#  'B00002DHEV': 551,
#  'B00002EIWS': 552,
#  'B00002EPYX': 553,
#  'B00002EPY0': 554,
#  'B00002EPY7': 555,
#  'B00002EPYV': 556,
#  'B00002EPYY': 557,
#  'B00002EPYB': 558,
#  'B00002EIX3': 559,
#  'B00002EPY8': 560,
#  'B00002EPY6': 561,
#  'B00002EPYK': 562,
#  'B00002EQAP': 563,
#  'B00002EPYE': 564,
#  'B00002EPYA': 565,
#  'B00002EPZ2': 566,
#  'B00002EIW5': 567,
#  'B00002EPY4': 568,
#  'B00002EIWU': 569,
#  'B00002EIZS': 570,
#  'B00002EPYJ': 571,
#  'B00002EPYI': 572,
#  'B00002EPGU': 573,
#  'B00002EPYC': 574,
#  'B00002EPY1': 575,
#  'B00002JXBC': 576,
#  'B00002K13U': 577,
#  'B00002JXBD': 578,
#  'B00002NDRR': 579,
#  'B00002NDEE': 580,
#  'B00002NDR7': 581,
#  'B00002NDSL': 582,
#  'B00002NDED': 583,
#  'B00002NDER': 584,
#  'B00002NDRY': 585,
#  'B00002R1XC': 586,
#  'B00002NDEF': 587,
#  'B00002R17B': 588,
#  'B00002R28N': 589,
#  'B00002R28F': 590,
#  'B00002R28K': 591,
#  'B00002R28O': 592,
#  'B00002R28C': 593,
#  'B00002NDSI': 594,
#  'B00002R28Q': 595,
#  'B00002R29G': 596,
#  'B00002NDRL': 597,
#  'B00002S6ED': 598,
#  'B00002S6EO': 599,
#  'B00002S6EY': 600,
#  'B00002R29R': 601,
#  'B00002S5Q0': 602,
#  'B00002R28T': 603,
#  'B00002S6CH': 604,
#  'B00002S6EL': 605,
#  'B00002R28I': 606,
#  'B00002S7IH': 607,
#  'B00002S7YR': 608,
#  'B00002S6EZ': 609,
#  'B00002S6CC': 610,
#  'B00002S6BL': 611,
#  'B00002S8AV': 612,
#  'B00002S85P': 613,
#  'B00002S93J': 614,
#  'B00002SA3S': 615,
#  'B00002SAMJ': 616,
#  'B00002S81H': 617,
#  'B00002SANR': 618,
#  'B00002S9SE': 619,
#  'B00002SAMQ': 620,
#  'B00002S7XF': 621,
#  'B00002S82C': 622,
#  'B00002SAMK': 623,
#  'B00002S9MO': 624,
#  'B00002S9O4': 625,
#  'B00002S9ZV': 626,
#  'B00002S7ZX': 627,
#  'B00002SFNO': 628,
#  'B00002S7U0': 629,
#  'B00002SANH': 630,
#  'B00002ST2R': 631,
#  'B00002ST2K': 632,
#  'B00002SSU3': 633,
#  'B00002ST2P': 634,
#  'B00002ST28': 635,
#  'B00002S8DH': 636,
#  'B00002ST2M': 637,
#  'B00002ST4U': 638,
#  'B00002ST4X': 639,
#  'B00002ST4N': 640,
#  'B00002ST7X': 641,
#  'B00002ST7A': 642,
#  'B00002ST83': 643,
#  'B00002ST36': 644,
#  'B00002ST37': 645,
#  'B00002ST7U': 646,
#  'B00002ST5K': 647,
#  'B00002ST82': 648,
#  'B00002ST6R': 649,
#  'B00002ST8C': 650,
#  'B00002SFNG': 651,
#  'B00002SSVH': 652,
#  'B00002ST6T': 653,
#  'B00002ST75': 654,
#  'B00002STAJ': 655,
#  'B00002ST7F': 656,
#  'B00002STAQ': 657,
#  'B00002STAU': 658,
#  'B00002ST7H': 659,
#  'B00002ST88': 660,
#  'B00002ST2A': 661,
#  'B00002ST7Z': 662,
#  'B00002STGI': 663,
#  'B00002STGT': 664,
#  'B00002STHO': 665,
#  'B00002STFF': 666,
#  'B00002STGE': 667,
#  'B00002ST3E': 668,
#  'B00002STF6': 669,
#  'B00002ST6O': 670,
#  'B00002STIF': 671,
#  'B00002STFP': 672,
#  'B00002ST2J': 673,
#  'B00002STGL': 674,
#  'B00002STGM': 675,
#  'B00002STJ8': 676,
#  'B00002STA1': 677,
#  'B00002STIY': 678,
#  'B00002STHX': 679,
#  'B00002STEZ': 680,
#  'B00002STIZ': 681,
#  'B00002STJG': 682,
#  'B00002STKO': 683,
#  'B00002STGU': 684,
#  'B00002STJP': 685,
#  'B00002STHN': 686,
#  'B00002STGD': 687,
#  'B00002ST6L': 688,
#  'B00002STH3': 689,
#  'B00002STJN': 690,
#  'B00002STGN': 691,
#  'B00002STA0': 692,
#  'B00002STFZ': 693,
#  'B00002STNL': 694,
#  'B00002STF7': 695,
#  'B00002STJ7': 696,
#  'B00002STOT': 697,
#  'B00002STOB': 698,
#  'B00002STKH': 699,
#  'B00002STIH': 700,
#  'B00002STK5': 701,
#  'B00002STJ5': 702,
#  'B00002STJO': 703,
#  'B00002STKR': 704,
#  'B00002ST78': 705,
#  'B00002STLK': 706,
#  'B00002ST5S': 707,
#  'B00002STEX': 708,
#  'B00002STH5': 709,
#  'B00002ST6Q': 710,
#  'B00002STPD': 711,
#  'B00002STQV': 712,
#  'B00002STLL': 713,
#  'B00002STJH': 714,
#  'B00002STI6': 715,
#  'B00002STJT': 716,
#  'B00002ST5T': 717,
#  'B00002STOW': 718,
#  'B00002STPY': 719,
#  'B00002STPX': 720,
#  'B00002STUI': 721,
#  'B00002ST27': 722,
#  'B00002ST8F': 723,
#  'B00002ST33': 724,
#  'B00002STIJ': 725,
#  'B00002STTW': 726,
#  'B00002STFN': 727,
#  'B00002STOX': 728,
#  'B00002STF3': 729,
#  'B00002STPE': 730,
#  'B00002STFH': 731,
#  'B00002ST7C': 732,
#  'B00002STI2': 733,
#  'B00002ST7D': 734,
#  'B00002STH4': 735,
#  'B00002STFO': 736,
#  'B00002STHV': 737,
#  'B00002STNP': 738,
#  'B00002STOA': 739,
#  'B00002STKN': 740,
#  'B00002STNQ': 741,
#  'B00002STQE': 742,
#  'B00002STVR': 743,
#  'B00002STTQ': 744,
#  'B00002STWP': 745,
#  'B00002STFD': 746,
#  'B00002STX4': 747,
#  'B00002STX3': 748,
#  'B00002STXQ': 749,
#  'B00002STXN': 750,
#  'B00002STH0': 751,
#  'B00002STIB': 752,
#  'B00002STQF': 753,
#  'B00002STTR': 754,
#  'B00002STGR': 755,
#  'B00002STRG': 756,
#  'B00002STQ4': 757,
#  'B00002STPG': 758,
#  'B00002STJA': 759,
#  'B00002ST7G': 760,
#  'B00002STYC': 761,
#  'B00002STJC': 762,
#  'B00002STKL': 763,
#  'B00002STKX': 764,
#  'B00002STYS': 765,
#  'B00002STZH': 766,
#  'B00002ST2I': 767,
#  'B00002ST79': 768,
#  'B00002STXG': 769,
#  'B00002STPF': 770,
#  'B00002STW1': 771,
#  'B00002STJ0': 772,
#  'B00002STL9': 773,
#  'B00002STYF': 774,
#  'B00002STPH': 775,
#  'B00002SU3D': 776,
#  'B00002STXO': 777,
#  'B00002SU5C': 778,
#  'B00002STKG': 779,
#  'B00002SU5A': 780,
#  'B00002STL0': 781,
#  'B00002STPL': 782,
#  'B00002STPC': 783,
#  'B00002STK3': 784,
#  'B00002STT1': 785,
#  'B00002ST8W': 786,
#  'B00002SU53': 787,
#  'B00002STFC': 788,
#  'B00002STQ0': 789,
#  'B00002STIW': 790,
#  'B00002SUC9': 791,
#  'B00002STJE': 792,
#  'B00002STJI': 793,
#  'B00002STYX': 794,
#  'B00002STXL': 795,
#  'B00002STKK': 796,
#  'B00002SU8F': 797,
#  'B00002SU5Q': 798,
#  'B00002STGZ': 799,
#  'B00002STZ6': 800,
#  'B00002STPS': 801,
#  'B00002SUPU': 802,
#  'B00002SUCX': 803,
#  'B00002STVN': 804,
#  'B00002SUNO': 805,
#  'B00002STPM': 806,
#  'B00002STXS': 807,
#  'B00002SUMA': 808,
#  'B00002STUJ': 809,
#  'B00002SUR0': 810,
#  'B00002STY9': 811,
#  'B00002SV5B': 812,
#  'B00002SUE9': 813,
#  'B00002STQ7': 814,
#  'B00002STIE': 815,
#  'B00002STXY': 816,
#  'B00002SVBZ': 817,
#  'B00002SV4A': 818,
#  'B00002STV1': 819,
#  'B00002SVET': 820,
#  'B00002SU5D': 821,
#  'B00002SULZ': 822,
#  'B00002SV61': 823,
#  'B00002SVBA': 824,
#  'B00002SVFW': 825,
#  'B00002SV0U': 826,
#  'B00002SVFK': 827,
#  'B00002SV58': 828,
#  'B00002SVG3': 829,
#  'B00002SV6G': 830,
#  'B00002SU3C': 831,
#  'B00002SVJU': 832,
#  'B00002SUDC': 833,
#  'B00002SUD0': 834,
#  'B00002SVFR': 835,
#  'B00002SVG2': 836,
#  'B00002SVER': 837,
#  'B00002SUM5': 838,
#  'B00002SV4N': 839,
#  'B00002SUV5': 840,
#  'B00002SVO1': 841,
#  'B00002SV55': 842,
#  'B00002SUCV': 843,
#  'B00002STV2': 844,
#  'B00002SUR7': 845,
#  'B00002SVNY': 846,
#  'B00002SVFQ': 847,
#  'B00002SVPC': 848,
#  'B00002SUHI': 849,
#  'B00002SVEM': 850,
#  'B00002SV0E': 851,
#  'B00002SVEO': 852,
#  'B00002SVFZ': 853,
#  'B00002SUOW': 854,
#  'B00002SVFV': 855,
#  'B00002STX6': 856,
#  'B00002SVEV': 857,
#  'B00002STYR': 858,
#  'B00002SVOJ': 859,
#  'B00002SVFX': 860,
#  'B00002SVBV': 861,
#  'B00002SVWB': 862,
#  'B00002SVUI': 863,
#  'B00002SVO9': 864,
#  'B00002SVX5': 865,
#  'B00002STYY': 866,
#  'B00002SVWE': 867,
#  'B00002SVOB': 868,
#  'B00002SW3J': 869,
#  'B00002SVOT': 870,
#  'B00002SU93': 871,
#  'B00002SVOL': 872,
#  'B00002STH2': 873,
#  'B00002SUZ5': 874,
#  'B00002STGV': 875,
#  'B00002SVWD': 876,
#  'B00002STF1': 877,
#  'B00002SW3I': 878,
#  'B00002SW3O': 879,
#  'B00002SVPA': 880,
#  'B00002SVO2': 881,
#  'B00002SVP7': 882,
#  'B00002SVOG': 883,
#  'B00002SVCR': 884,
#  'B00002SUCW': 885,
#  'B00002SW4M': 886,
#  'B00002SW3N': 887,
#  'B00002SW2O': 888,
#  'B00002SVG7': 889,
#  'B00002SVFM': 890,
#  'B00002SUOV': 891,
#  'B00002SWA8': 892,
#  'B00002SW25': 893,
#  'B00002SUO5': 894,
#  'B00002STZI': 895,
#  'B00002SWF8': 896,
#  'B00002SVWA': 897,
#  'B00002SVX6': 898,
#  'B00002SV9V': 899,
#  'B00002SU0O': 900,
#  'B00002SVES': 901,
#  'B00002SVCS': 902,
#  'B00002SW3L': 903,
#  'B00002SW4D': 904,
#  'B00002SVYB': 905,
#  'B00002SVF4': 906,
#  'B00002SV6D': 907,
#  'B00002SUIK': 908,
#  'B00002ST3U': 909,
#  'B00002SWA2': 910,
#  'B00002SVJW': 911,
#  'B00002SVRC': 912,
#  'B00002STVO': 913,
#  'B00002SWA1': 914,
#  'B00002SV6T': 915,
#  'B00002SUCS': 916,
#  'B00002SWBG': 917,
#  'B00002SVML': 918,
#  'B00002SUYX': 919,
#  'B00002SVOE': 920,
#  'B00002STGQ': 921,
#  'B00002SVG0': 922,
#  'B00002SX0H': 923,
#  'B00002SUPP': 924,
#  'B00002SWCO': 925,
#  'B00002SWF4': 926,
#  'B00002SVOY': 927,
#  'B00002SVMG': 928,
#  'B00002SUAD': 929,
#  'B00002SW3P': 930,
#  'B00002SVMJ': 931,
#  'B00002SX0E': 932,
#  'B00002SW8P': 933,
#  'B00002SX0F': 934,
#  'B00002SW4F': 935,
#  'B00002Z72E': 936,
#  'B00002SVF6': 937,
#  'B00002SW4J': 938,
#  'B00002SVWG': 939,
#  'B00002STYU': 940,
#  'B0000302P8': 941,
#  'B00003031F': 942,
#  'B00003065G': 943,
#  'B00003069T': 944,
#  'B000031KJW': 945,
#  'B000031KAG': 946,
#  'B000031KJL': 947,
#  'B000031KJH': 948,
#  'B000031KJM': 949,
#  'B000031KJQ': 950,
#  'B000031KJX': 951,
#  'B000031WCQ': 952,
#  'B000034DD1': 953,
#  'B000031KJI': 954,
#  'B000031KJY': 955,
#  'B000034DMP': 956,
#  'B000034DC6': 957,
#  'B000034DEB': 958,
#  'B000034DC8': 959,
#  'B000033K1F': 960,
#  'B000034DC7': 961,
#  'B000031KAS': 962,
#  'B000034DMG': 963,
#  'B000034DJ5': 964,
#  'B000035XGF': 965,
#  'B000035XGL': 966,
#  'B000035XB0': 967,
#  'B000035XI2': 968,
#  'B000035XAY': 969,
#  'B000034DML': 970,
#  'B000034DLH': 971,
#  'B000034DBS': 972,
#  'B000035XKJ': 973,
#  'B000035XIH': 974,
#  'B000035XJD': 975,
#  'B000035XLO': 976,
#  'B000035XII': 977,
#  'B000035XKY': 978,
#  'B000035XJB': 979,
#  'B000035XHV': 980,
#  'B000035XMT': 981,
#  'B000034DE9': 982,
#  'B000035XIJ': 983,
#  'B000035XKU': 984,
#  'B000035XMK': 985,
#  'B000035XIV': 986,
#  'B000035XBG': 987,
#  'B000035XK9': 988,
#  'B000035XPI': 989,
#  'B000035XJX': 990,
#  'B000035XMR': 991,
#  'B000035XN2': 992,
#  'B000035XQ0': 993,
#  'B000035XNC': 994,
#  'B000035XQ6': 995,
#  'B000035XQG': 996,
#  'B000035XLN': 997,
#  'B000035XLE': 998,
#  'B000035XI6': 999,
#  ...}

# %%
df['asin'] = df['asin'].map(asin_map)

# %%
df
# Out:
#           asin            user  rating   timestamp
# 0            0  A21ROB4YDOZA5P     1.0  1402272000
# 1            0  A3TNZ2Q5E7HTHD     3.0  1399680000
# 2            0  A1OKRM3QFEATQO     4.0  1391731200
# 3            0  A2XO1JFCNEYV3T     1.0  1391731200
# 4            0  A19WLPIRHD15TH     4.0  1389830400
# ...        ...             ...     ...         ...
# 2565344  25455   ANGB54K3888S4     5.0  1533081600
# 2565345  25455  A3TEVKR0ZVQB2T     5.0  1531785600
# 2565346  25455   ABE7YPWEHNVJZ     5.0  1530835200
# 2565347  25455  A3ES9QBK3G192O     5.0  1528761600
# 2565348  25455  A194UPGR3OXZB7     5.0  1524096000
#
# [2565349 rows x 4 columns]

# %%
df['asin'].map(asin_lookup)
# Out:
# 0          0439381673
# 1          0439381673
# 2          0439381673
# 3          0439381673
# 4          0439381673
#               ...
# 2565344    B01HJEBIAA
# 2565345    B01HJEBIAA
# 2565346    B01HJEBIAA
# 2565347    B01HJEBIAA
# 2565348    B01HJEBIAA
# Name: asin, Length: 2565349, dtype: object

# %%
df['asin'].nunique()
# Out:
# 71982

# %%
df['user'].nunique()
# Out:
# 1540618

# %%
df=df.sample(frac=1)

# %%
df['rating'].value_counts()
# Out:
# 5.0    1447324
# 4.0     397993
# 1.0     302251
# 3.0     205656
# 2.0     136972
# Name: rating, dtype: int64

# %%
df.dtypes
# Out:
# asin          object
# user          object
# rating       float64
# timestamp      int64
# dtype: object

# %%
df.isna().sum()
# Out:
# asin         0
# user         0
# rating       0
# timestamp    0
# dtype: int64

# %%
df[df.duplicated(keep=False)==True].head(20)
# Out:
#                asin            user  rating   timestamp
# 1782415  B00SN1QEGW   A71Z5AIGEFK11     5.0  1532995200
# 550506   B0013016O0  A2EJIPSUG5J6NH     4.0  1228521600
# 464001   B000ZK698C   A35WDB667ARZU     5.0  1406851200
# 475396   B0012N8WXQ   A534OK7WDYERU     5.0  1348444800
# 579797   B0017IUFAE  A2336BHPQW6UQH     5.0  1329436800
# 566814   B00163EWQI  A3KBYGS21NC80X     4.0  1414368000
# 518876   B000WMEEAI  A2QRWCIV0Z4QMF     5.0  1484697600
# 472225   B00128CH7S   AQITO3THZGYBR     5.0  1300579200
# 461728   B000ZK9QCS  A2FKZC2P6K3O99     5.0  1314576000
# 478705   B0013E9HP6  A299YIRXVGEJM6     5.0  1445299200
# 552963   B0013E9HP6  A1SV6UNQCJJDQY     4.0  1388793600
# 499279   B0016O5G62  A169YL3N5HBSNO     5.0  1228953600
# 517946   B000WDUGB8  A2FIGHUA3B2HRZ     5.0  1204502400
# 477113   B00136MBHA   A4WC955MUXPC5     5.0  1455753600
# 4098     B00000DMAQ  A1CDNTB7377YH2     5.0  1178150400
# 546760   B0012FJX96  A27PLKK3FC1X45     4.0  1218931200
# 463382   B000ZKA0J6  A2904F58B1I3Q9     1.0  1280275200
# 471528   B0011V2HR6   AXRF2RO8P6LNJ     5.0  1247097600
# 437735   B000VJTJNE  A38L7XLJYEWZP5     1.0  1348963200
# 514339   B000VSBKCI  A1IVSJNDU95L3P     5.0  1406851200

# %%
df[(df['user']=='AF3EVH5OFWIQN') & (df['asin']=='1300450991')]
# Out:
# Empty DataFrame
# Columns: [asin, user, rating, timestamp]
# Index: []

# %%
df[df.duplicated(keep=False)==False].head(20)
# Out:
#                asin            user  rating   timestamp
# 1431057  B00FWWY1V0  A19Y6MQ2928NX6     2.0  1411516800
# 2345048  B002C92OP6  A1ZQ8PVBNGZPOM     1.0  1258156800
# 642026   B001H0RZX2  A15H0U1SHC4VI1     5.0  1242345600
# 2235464  B0002FQVBA  A142B0CTP2PUBB     4.0  1428796800
# 1634890  B00KY0QH0I   AY5651M8C8NR8     5.0  1412726400
# 2545630  B01BKY707K  A2ZY4LWSNB68O9     3.0  1527206400
# 1554013  B00JKM06EO  A1T2DNKLHYWP80     5.0  1501200000
# 1110690  B008DBJPLS  A34X974YQ9BYRX     5.0  1429660800
# 195840   B00022GIYI   AKRH6V60MHFNZ     5.0  1089936000
# 2558980  B01FVLA43A  A37FYBF0IUWQIW     5.0  1504310400
# 1642149  B00L6AVNE0  A3EVHBOSCT1N3Q     5.0  1409961600
# 1207363  B00BGA9X9W  A1MXDUZZ2U79PC     5.0  1528156800
# 1859765  B00YJJ0OQS  A2MWLCYZ85NZBS     4.0  1474934400
# 755691   B002I096Q4  A3RLXL0W2SZFB2     5.0  1413244800
# 1134783  B0095D1CM8  A15KGTIWXURY2S     4.0  1387670400
# 1737276  B00OXT579S  A254UOM1Z1NG86     5.0  1454371200
# 1571236  B00K2ZV13I  A3GBBTB5FHVVP1     5.0  1416787200
# 877324   B004KKI7XI  A1P9CEL6YGJPP5     5.0  1438992000
# 1718404  B00NY5ZPF8  A15N52TSKNW14Z     4.0  1449619200
# 1438933  B00GANWVJE  A3FZ2MDB3P05Y9     5.0  1388620800

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                asin            user  rating   timestamp
# 1431057  B00FWWY1V0  A19Y6MQ2928NX6     2.0  1411516800
# 2345048  B002C92OP6  A1ZQ8PVBNGZPOM     1.0  1258156800
# 642026   B001H0RZX2  A15H0U1SHC4VI1     5.0  1242345600
# 2235464  B0002FQVBA  A142B0CTP2PUBB     4.0  1428796800
# 1634890  B00KY0QH0I   AY5651M8C8NR8     5.0  1412726400
# ...             ...             ...     ...         ...
# 679714   B001TOQ8K2  A1RXC1H08QBH2T     5.0  1448236800
# 1648286  B00LLBZINQ  A1Y9UC4APAI599     4.0  1415491200
# 1214449  B00BGD6LMG  A1YWA9YV80SYGB     5.0  1421193600
# 2209424  B000063RRK   A5VDI4RFJ4X8W     5.0  1033948800
# 1949006  B0149HT55K  A2UYTAVLM5J8X5     4.0  1461974400
#
# [2490196 rows x 4 columns]

# %%
df['rating'].value_counts(normalize=True).sort_index(ascending=False)
# Out:
# 5.0    0.581209
# 4.0    0.159824
# 3.0    0.082586
# 2.0    0.055005
# 1.0    0.121376
# Name: rating, dtype: float64

# %%
df['asin'].nunique()
# Out:
# 71982

# %%
df['user'].nunique()
# Out:
# 1540618

# %%
meta_df = pd.read_json('data/meta_Video_Games.json.gz', lines=True)
meta_df
# Out:
#                                                 category  \
# 0                               [Video Games, PC, Games]
# 1      [Video Games, Xbox 360, Games, </span></span><...
# 2      [Video Games, Retro Gaming & Microconsoles, Su...
# 3      [Video Games, Xbox 360, Accessories, Controlle...
# 4      [Video Games, PC, Games, </span></span></span>...
# ...                                                  ...
# 84814  [Video Games, PlayStation Vita, Digital Games ...
# 84815  [Video Games, PlayStation 4, Digital Games & D...
# 84816  [Video Games, PlayStation 4, Digital Games & D...
# 84817  [Video Games, Xbox 360, Accessories, </span></...
# 84818        [Video Games, PC, Accessories, Gaming Mice]
#
#                                                    tech1  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 84814
# 84815
# 84816
# 84817
# 84818   class="a-keyvalue prodDetTable" role="present...
#
#                                              description fit  \
# 0                                                     []
# 1                                    [Brand new sealed!]
# 2                                                     []
# 3      [MAS's Pro Xbox 360 Stick (Perfect 360 Stick) ...
# 4      [Phonics Alive! 3, The Speller teaches student...
# ...                                                  ...  ..
# 84814  [<div>The Force is strong with this one The No...
# 84815  [<div>The Season Pass includes three Level Pac...
# 84816  [<div>The Technomancer takes you to Mars, wher...
# 84817  [<b>FUNCTIONS:</b><br> 1.Take apart your Xbox ...
# 84818  [<b>Features and Functions:</b> <br>Quick thum...
#
#                                                    title  \
# 0                             Reversi Sensory Challenger
# 1      Medal of Honor: Warfighter - Includes Battlefi...
# 2      street fighter 2 II turbo super nintendo snes ...
# 3                                     Xbox 360 MAS STICK
# 4                          Phonics Alive! 3: The Speller
# ...                                                  ...
# 84814  Lego Star Wars: The Force Awakens - PS Vita [D...
# 84815  Lego Star Wars: The Force Awakens  Season Pass...
# 84816              The Technomancer - PS4 [Digital Code]
# 84817  Repair T8 T6 Tools for XBOX One Xbox 360, YTTL...
# 84818  Zelotes 4000 DPI Programmable Gaming Mouse for...
#
#                                                 also_buy tech2  \
# 0                                                     []
# 1                                           [B00PADROYW]
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...   ...
# 84814                                                 []
# 84815                                                 []
# 84816                                                 []
# 84817  [B01KBNB7K2, B06X6JSYPC, B01N6Y0Z7W, B06VXD2W5...
# 84818                                                 []
#
#                                            brand  \
# 0                           Fidelity Electronics
# 1                         by\n    \n    EA Games
# 2                                       Nintendo
# 3                      by\n    \n    MAS SYSTEMS
# 4      by\n    \n    Advanced Software Pty. Ltd.
# ...                                          ...
# 84814                 by\n    \n    Warner Bros.
# 84815                 by\n    \n    Warner Bros.
# 84816       by\n    \n    Focus Home Interactive
# 84817                         by\n    \n    YTTL
# 84818                                    Zelotes
#
#                                                  feature  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3      [Original PCB used from Xbox 360 Control Pad (...
# 4      [Grades 2-12, Spelling Program, Teaches Spelli...
# ...                                                  ...
# 84814                                                 []
# 84815                           [DLC Requires base game]
# 84816                                                 []
# 84817  [If you want to Replacement you Xbox one /360 ...
# 84818  [Customize DPI Switch: 1000/1500/2000/4000,the...
#
#                                                     rank  \
# 0      [>#2,623,937 in Toys &amp; Games (See Top 100 ...
# 1      [>#67,231 in Video Games (See Top 100 in Video...
# 2      [>#134,433 in Video Games (See Top 100 in Vide...
# 3      [>#105,263 in Video Games (See Top 100 in Vide...
# 4      [>#92,397 in Video Games (See Top 100 in Video...
# ...                                                  ...
# 84814  [>#74,224 in Video Games (See Top 100 in Video...
# 84815  [>#62,150 in Video Games (See Top 100 in Video...
# 84816  [>#94,234 in Video Games (See Top 100 in Video...
# 84817  [>#16,087 in Video Games (See Top 100 in Video...
# 84818  [>#434 in Computers & Accessories > Computer A...
#
#                                                also_view          main_cat  \
# 0                                                     []  Toys &amp; Games
# 1      [B0050SY5BM, B072NQJCW5, B000TI836G, B002SRSQ7...       Video Games
# 2                                                     []       Video Games
# 3                                                     []       Video Games
# 4                                           [B000BCZ7U0]       Video Games
# ...                                                  ...               ...
# 84814                                                 []       Video Games
# 84815                                                 []       Video Games
# 84816                                                 []       Video Games
# 84817  [B01KH25ZY6, B00PG8SU26, B07G122BVS, B016XLTQP...       Video Games
# 84818  [B016ZF77OA, B00GU8W5AE, B00E64DTDQ, B074TF6XV...         Computers
#
#       similar_item           date  \
# 0
# 1
# 2
# 3
# 4
# ...            ...            ...
# 84814
# 84815
# 84816
# 84817
# 84818               June 25, 2016
#
#                                                    price        asin  \
# 0                                                         0042000742
# 1      \n\t\t\t\t\t\t\t\t\t\t\t\t<span class="vertica...  0078764343
# 2                                                  $0.72  0276425316
# 3                                                         0324411812
# 4                                                         0439335310
# ...                                                  ...         ...
# 84814                                                     B01HJ1521Y
# 84815  \n\t\t                                        ...  B01HJ14TTA
# 84816                                                     B01HJ14OT0
# 84817  \n\t\t\t\t\t\t\t\t\t\t\t\t<span class="vertica...  B01HJC33WS
# 84818                                             $23.99  B01HJEBIAA
#
#                                                 imageURL  \
# 0      [https://images-na.ssl-images-amazon.com/image...
# 1      [https://images-na.ssl-images-amazon.com/image...
# 2                                                     []
# 3      [https://images-na.ssl-images-amazon.com/image...
# 4      [https://images-na.ssl-images-amazon.com/image...
# ...                                                  ...
# 84814                                                 []
# 84815                                                 []
# 84816  [https://images-na.ssl-images-amazon.com/image...
# 84817  [https://images-na.ssl-images-amazon.com/image...
# 84818  [https://images-na.ssl-images-amazon.com/image...
#
#                                          imageURLHighRes details
# 0      [https://images-na.ssl-images-amazon.com/image...     NaN
# 1      [https://images-na.ssl-images-amazon.com/image...     NaN
# 2                                                     []     NaN
# 3      [https://images-na.ssl-images-amazon.com/image...     NaN
# 4      [https://images-na.ssl-images-amazon.com/image...     NaN
# ...                                                  ...     ...
# 84814                                                 []      {}
# 84815                                                 []      {}
# 84816  [https://images-na.ssl-images-amazon.com/image...      {}
# 84817  [https://images-na.ssl-images-amazon.com/image...      {}
# 84818  [https://images-na.ssl-images-amazon.com/image...      {}
#
# [84819 rows x 19 columns]

# %%
meta_df = meta_df[['title', 'asin']]

# %%
merged_df = df.merge(meta_df, how='inner', on='asin')
merged_df
# Out:
#                asin            user  rating   timestamp  \
# 0        B00FWWY1V0  A19Y6MQ2928NX6     2.0  1411516800
# 1        B00FWWY1V0  A2IOLR781CHYDE     5.0  1413417600
# 2        B00FWWY1V0   AN8SBLH1T2MXG     5.0  1388448000
# 3        B00FWWY1V0   A94EZP705DDOY     5.0  1450051200
# 4        B00FWWY1V0  A2TMASRK1MNWZ2     2.0  1391126400
# ...             ...             ...     ...         ...
# 2770597  B002XDLLB4   AM3ICG8AUMFUX     5.0  1362614400
# 2770598  B0043M64GA  A27EBTIQEO2XGC     1.0  1330128000
# 2770599  B00006LJUR  A1BQKZ2IIKXQF4     5.0  1391385600
# 2770600  B00006LJUR  A1BQKZ2IIKXQF4     5.0  1391385600
# 2770601  B00JH15IU0  A1CYNOBY1IIPLP     1.0  1483488000
#
#                                                      title
# 0        KontrolFreek FPS Freek Phantom for PlayStation...
# 1        KontrolFreek FPS Freek Phantom for PlayStation...
# 2        KontrolFreek FPS Freek Phantom for PlayStation...
# 3        KontrolFreek FPS Freek Phantom for PlayStation...
# 4        KontrolFreek FPS Freek Phantom for PlayStation...
# ...                                                    ...
# 2770597  God War PS3 Playstation 3 Body Protector Skin ...
# 2770598                                       Dead Space 2
# 2770599  Valkyrie Profile [Limited Deluxe Pack] [Japan ...
# 2770600  Valkyrie Profile [Limited Deluxe Pack] [Japan ...
# 2770601  PS4 Console Designer Skin for Sony PlayStation...
#
# [2770602 rows x 5 columns]

# %%
merged_df.tail(20)
# Out:
#                asin            user  rating   timestamp  \
# 2770582  B000R7YDJU  A1JRYELA59GKH2     5.0  1410825600
# 2770583  B0001RBMMC  A33FVFKPMPAVLV     4.0  1363478400
# 2770584  B0001RBMMC  A33FVFKPMPAVLV     4.0  1363478400
# 2770585  B00YFQM6N4  A2Q14TLLNVHPJA     5.0  1483920000
# 2770586  B000069T8M  A2MJIKNJ8JHDPZ     4.0  1381795200
# 2770587  B000069T8M  A2MJIKNJ8JHDPZ     4.0  1381795200
# 2770588  B005553P2A  A24X3S2YINEYYR     2.0  1439164800
# 2770589  B00R06VT5C  A24AV8V31CGZY8     5.0  1481673600
# 2770590  B00AC41M6A  A1O17XN1STC1UT     5.0  1369872000
# 2770591  B001FSKJZW  A258RT106MZYOM     3.0  1443916800
# 2770592  B00006IQJR  A28H9CEESMTFJZ     3.0  1339891200
# 2770593  B00006IQJR  A28H9CEESMTFJZ     3.0  1339891200
# 2770594  B00699IYJ0  A1IP74DFYDSNU7     5.0  1389571200
# 2770595  B00V65C8L2  A351KJBNTH7U65     5.0  1477180800
# 2770596  B00ME76IT4  A2X99XA8HWSAN6     4.0  1411084800
# 2770597  B002XDLLB4   AM3ICG8AUMFUX     5.0  1362614400
# 2770598  B0043M64GA  A27EBTIQEO2XGC     1.0  1330128000
# 2770599  B00006LJUR  A1BQKZ2IIKXQF4     5.0  1391385600
# 2770600  B00006LJUR  A1BQKZ2IIKXQF4     5.0  1391385600
# 2770601  B00JH15IU0  A1CYNOBY1IIPLP     1.0  1483488000
#
#                                                      title
# 2770582                                       SPROINK - PC
# 2770583                  4mb Memory Card (Japanese Import)
# 2770584                  4mb Memory Card (Japanese Import)
# 2770585  Legend of Zelda Link Ocarina 3D of Time Epona ...
# 2770586           Sonic 3D: Flicky's Island [Japan Import]
# 2770587           Sonic 3D: Flicky's Island [Japan Import]
# 2770588  Final Fantasy Crystal Chronicles:The Crystal B...
# 2770589  MODFREAKZ Pair of Vinyl Controller Skins - Fly...
# 2770590                  The Game Chamber DS Game Vault 12
# 2770591       Sengoku Basara: Battle Heroes [Japan Import]
# 2770592       Ultraman Fighting Evolution 2 [Japan Import]
# 2770593       Ultraman Fighting Evolution 2 [Japan Import]
# 2770594  Solids Xbox 360 Wireless Controller Skin - Ora...
# 2770595    IS-Infinite Stratos-2 Love &amp; Purge(PS Vita)
# 2770596  Small Town Terrors Pilgrim's Hook - Collector'...
# 2770597  God War PS3 Playstation 3 Body Protector Skin ...
# 2770598                                       Dead Space 2
# 2770599  Valkyrie Profile [Limited Deluxe Pack] [Japan ...
# 2770600  Valkyrie Profile [Limited Deluxe Pack] [Japan ...
# 2770601  PS4 Console Designer Skin for Sony PlayStation...

# %%
merged_df['user'].nunique()
# Out:
# 1539732

# %%
merged_df['title'].nunique()
# Out:
# 68663

# %%
merged_df.isna().sum()
# Out:
# asin         0
# user         0
# rating       0
# timestamp    0
# title        0
# dtype: int64

# %%
merged_df[merged_df.duplicated(keep=False)==True].head(20)
# Out:
#            asin            user  rating   timestamp  \
# 832  B0002FQVBA  A142B0CTP2PUBB     4.0  1428796800
# 833  B0002FQVBA  A142B0CTP2PUBB     4.0  1428796800
# 834  B0002FQVBA  A20ZBW8WN0MEMT     5.0  1119916800
# 835  B0002FQVBA  A20ZBW8WN0MEMT     5.0  1119916800
# 836  B0002FQVBA  A2WW5VUQN2JFMC     4.0  1116288000
# 837  B0002FQVBA  A2WW5VUQN2JFMC     4.0  1116288000
# 838  B0002FQVBA   APUIZOMJCYQ6F     3.0  1114905600
# 839  B0002FQVBA   APUIZOMJCYQ6F     3.0  1114905600
# 840  B0002FQVBA  A2H8UCVKM5YFF8     3.0  1114560000
# 841  B0002FQVBA  A2H8UCVKM5YFF8     3.0  1114560000
# 842  B0002FQVBA   A7SZ8WY5OTDIR     2.0  1096761600
# 843  B0002FQVBA   A7SZ8WY5OTDIR     2.0  1096761600
# 844  B0002FQVBA  A107M7ZYK75X5H     1.0  1115424000
# 845  B0002FQVBA  A107M7ZYK75X5H     1.0  1115424000
# 846  B0002FQVBA   AU83EYNTH6WU9     1.0  1131753600
# 847  B0002FQVBA   AU83EYNTH6WU9     1.0  1131753600
# 848  B0002FQVBA  A1ADG449ZNEO6Y     5.0  1125532800
# 849  B0002FQVBA  A1ADG449ZNEO6Y     5.0  1125532800
# 850  B0002FQVBA  A27S1WDAK8QZJ8     4.0  1479081600
# 851  B0002FQVBA  A27S1WDAK8QZJ8     4.0  1479081600
#
#                                    title
# 832  Close Combat: First to Fight - Xbox
# 833  Close Combat: First to Fight - Xbox
# 834  Close Combat: First to Fight - Xbox
# 835  Close Combat: First to Fight - Xbox
# 836  Close Combat: First to Fight - Xbox
# 837  Close Combat: First to Fight - Xbox
# 838  Close Combat: First to Fight - Xbox
# 839  Close Combat: First to Fight - Xbox
# 840  Close Combat: First to Fight - Xbox
# 841  Close Combat: First to Fight - Xbox
# 842  Close Combat: First to Fight - Xbox
# 843  Close Combat: First to Fight - Xbox
# 844  Close Combat: First to Fight - Xbox
# 845  Close Combat: First to Fight - Xbox
# 846  Close Combat: First to Fight - Xbox
# 847  Close Combat: First to Fight - Xbox
# 848  Close Combat: First to Fight - Xbox
# 849  Close Combat: First to Fight - Xbox
# 850  Close Combat: First to Fight - Xbox
# 851  Close Combat: First to Fight - Xbox

# %%
from surprise import Dataset, Reader
from surprise import accuracy
from surprise.prediction_algorithms import knns
from surprise.similarities import cosine, msd, pearson
from surprise.model_selection import cross_validate, train_test_split
from surprise.prediction_algorithms import SVD
from surprise.model_selection import GridSearchCV

# %%
data= merged_df[['user', 'title', 'rating']]
reader= Reader(line_format= 'user item rating', sep= ',')
data= Dataset.load_from_df(data, reader=reader)

# %%
trainset, testset= train_test_split(data, test_size=0.25, random_state=42)

# %%
testset
# Out:
# [('A1ZOBRYGBL5OD1', 'Dragon Age Inquisition - Deluxe Edition - PC', 5.0),
#  ('AQW328WL34MNQ',
#   'Animal Crossing:  Happy Home Designer - 3DS [Digital Code]',
#   4.0),
#  ('A26VTX5W1NWTUF', 'Pokemon, Crystal Version', 5.0),
#  ('A2Y4NXYIKCR5EU', 'Dying Light - PlayStation 4', 5.0),
#  ('A87SK4BBWBI8Q',
#   'Modern-Tech Nintendo DSi XL High Capacity 2000 mAh Replacement Battery',
#   4.0),
#  ('A319B5UXCJQW8B', 'DmC Devil May Cry', 5.0),
#  ('A19QPUTHGBZN3Z', 'Spy vs Spy', 3.0),
#  ('A36V0ID0XVBW10',
#   'The Elder Scrolls V: Skyrim Special Edition - PS4 [Digital Code]',
#   5.0),
#  ('A77J3FEM7573',
#   'Mayflash GameCube Controller Adapter for Wii U, PC USB and Switch, 4 Port',
#   5.0),
#  ('A3RYR8X088WP7D',
#   'World of Tanks-X360 Xbox 360 English US NTSC DVD - Xbox 360',
#   1.0),
#  ('A2CYOFT3EMRCX1', 'Kingdoms of Amalur: Reckoning - PS3 [Digital Code]', 5.0),
#  ('A3REF9LD0INKRI', ' Majesty 2', 3.0),
#  ('A21EKIKJ2WWKDQ', 'Xenoblade Chronicles X', 5.0),
#  ('A28MNVWDTIABGC', 'At Games ATARI Flashback 4 Deluxe Edition', 5.0),
#  ('AWHCSMF9LVIZO', 'PDP Disney Infinity Play Zone', 5.0),
#  ('A1GM0X44OQRE0T',
#   'PDP Xbox One Afterglow LVL 3 Stereo Gaming Headset 048-041, Black',
#   3.0),
#  ('A1P15GNUNRUCRU',
#   'New Super Mario Bros. U Decorative Decal Cover Skin for Nintendo Wii U Console and GamePad',
#   4.0),
#  ('A3JAT44J8TKSLS', "Dragon's Crown - PlayStation Vita", 5.0),
#  ('A36KWPURBYU2ZK', 'PDP Wired Controller for Xbox One &amp; PC - Camo', 5.0),
#  ('AEVPQDZOBXPOZ', 'Battle Stadium D.O.N. [Japan Import]', 5.0),
#  ('A1H44B6T5ET34G', 'Ni Hao, Kai-Lan: Super Game Day - Nintendo Wii', 5.0),
#  ('A2KBMS1LOQ16UR',
#   'Tt eSPORTS HT-SHK002ECYE Thermaltake SHOCK Gaming Headset, Yellow',
#   1.0),
#  ('AUCQ7GVOXOETY', 'FIFA 17 - PlayStation 4', 5.0),
#  ('A2JE7DTDOJWLQ9',
#   'PlayStation 3 Dualshock 3 Wireless Controller (Candy Pink)',
#   5.0),
#  ('A383NM9QOYYELP',
#   "Guitar Hero 3-Disc Set with Guitar Hero I, Guitar Hero II and Guitar Hero 80's Encore - PlayStation 2",
#   5.0),
#  ('A1DOJMZHPKJ5A0', 'Bravely Default - Nintendo 3DS', 5.0),
#  ('A6OADNIAV6N7Q', 'Overwatch - Origins Edition - Xbox One', 4.0),
#  ('A1L2MFNF3HE0VF', 'Resident Evil: Code Veronica X - PlayStation 2', 3.0),
#  ('A2MGZ58GX8IBPJ', 'Delta Force Black Hawk Down - Xbox', 1.0),
#  ('AY4WE4ONB6HPR',
#   'Plantronics RIG Stereo Gaming Headset with Mixer for PC/Mac - Retail Packaging - Black',
#   3.0),
#  ('A3EOMAOP9RYWHF', 'Dr. Mario', 5.0),
#  ('A1IIBMM1GEAXQ',
#   'PlayStation 4 500GB Console - Star Wars Battlefront Bundle[Discontinued]',
#   4.0),
#  ('A10YGP23KD5P67', 'Far Cry 4 - PlayStation 4', 5.0),
#  ('A3A5M20ULQ9ESM', 'Sniper Elite III Ultimate Edition - PlayStation 4', 5.0),
#  ('A2168YYCKEPNPR',
#   'Turtle Beach - Ear Force Recon 30X Chat Communicator Gaming Headset - Xbox One (Discontinued by Manufacturer)',
#   4.0),
#  ('A2TILB1EXFILYC',
#   'ECOOPRO Stereo Gaming Headset with Microphone &ndash; 3.5mm Over Ear Headphones &ndash; LED Lights &amp; In-line Volume Control for PS4, PC, MAC, Mobiles Red',
#   1.0),
#  ('A21RRCEUIZR4Z5', 'Kirby Super Star Ultra', 5.0),
#  ('A34PCCROYXQM77',
#   'SpongeBob SquarePants: The Battle for Bikini Bottom - GameCube',
#   5.0),
#  ('A2H96Z5J6Q2UZ', 'Monster Hunter 4G [Japan Import]', 5.0),
#  ('A3NMVEQ5XCSS1G', 'World Soccer winning Eleven 7 International', 5.0),
#  ('A3O6XS52TY18KZ', 'Black &amp; White - PC', 1.0),
#  ('A3HWDFRZ6ITP77', 'Star Wars: Empire at War - PC', 5.0),
#  ('A28QQLZKCH4IU3',
#   'Nintendo 3DS XL (Not for &quot;New 3DS XL&quot;) FULL Aluminum Metal Case Protector Cover + Free Screen Protectors (GREEN)',
#   5.0),
#  ('A1M3UWVDT0VSP0',
#   'Bowser Jr. amiibo - Japan Import (Super Smash Bros Series)',
#   5.0),
#  ('A1XHW2KD478BT2', "Dante's Inferno Divine Edition - Playstation 3", 5.0),
#  ('AHJ8BT6HG4L0Z', 'Top Gun Fire At Will - Playstation', 4.0),
#  ('A1OO06PEUKLURO',
#   'Generic-3 Pack Combo Protective Silicone Case for Sony Playstation 4 Ps4 Controller- Camouflage Red / Blue / Green Color',
#   5.0),
#  ('A1PZ18IXPZNXUI', 'FIFA 15 - Xbox 360', 5.0),
#  ('A2IQ3XAHFO106V',
#   'Microsoft Flight Simulator 2004: A Century of Flight - PC',
#   2.0),
#  ('A3MA52OJC03LUF', 'PlayStation 2 Console (Slim Line Version 1)', 2.0),
#  ('A8ZXD7VCTBRWN',
#   'DualShock 4 Wireless Controller for PlayStation 4 - Jet Black [Old Model]',
#   5.0),
#  ('A3LOT70VYHBZCT', 'Dead or Alive 2', 5.0),
#  ('APHGR71JOB89P',
#   "Razer DeathAdder Chroma - Multi-Color Ergonomic Gaming Mouse - 10,000 DPI Sensor - Comfortable Grip - World's Most Popular Gaming Mouse",
#   5.0),
#  ('A3OWSI74I0QLMS',
#   'Enhanced Thumb Grips Quad Pack BRAND NEW for Playstation Vita',
#   5.0),
#  ('A2XIOXRRYX0KZY', 'Steam Controller', 4.0),
#  ('A3UGRCH61L7WOU', 'Mario Kart 8 - Nintendo Wii U', 4.0),
#  ('A259TNWSVEZ11W',
#   'VersionTECH. G2000 Stereo Gaming Headset for Xbox One PS4 PC, Surround Sound Over-Ear Headphones with Noise Cancelling Mic, LED Lights, Volume Control for Laptop, Mac, iPad, Nintendo Switch Games -Blue',
#   1.0),
#  ('A2I00AB5AANL3Q', 'PlayStation 2X Network Adaptor', 5.0),
#  ('A2PW5PHCP4H2EA', ' Spongebob Truth Or Square - Nintendo DS', 5.0),
#  ('A3LNIFW9VI9XON',
#   'Turtle Beach - Ear Force PX22 Universal Amplified Gaming Headset - PS3, Xbox 360, PC',
#   1.0),
#  ('A2LHH68JKVDOX2',
#   'Metal Gear Solid V: Ground Zeroes - Xbox 360 Standard Edition',
#   5.0),
#  ('A14DZD07SY8IT6', 'Nintendo DS Bundle with Metroid Prime Hunters Demo', 5.0),
#  ('A2FXOPHF0TMXU1',
#   'Kirby amiibo - Japan Import (Super Smash Bros Series)',
#   5.0),
#  ('A3648E6P9GOS1X', 'Rise of the Tomb Raider - Xbox One', 5.0),
#  ('A27YUZ4HZHPWUU', 'Crash Bandicoot: The Wrath of Cortex', 3.0),
#  ('ARC3Q902VVMJ2', "Castlevania II: Belmont's Revenge", 5.0),
#  ('A231MUXYZAQIZD',
#   'UtechSmart Venus 16400 DPI High Precision Laser MMO Gaming Mouse',
#   5.0),
#  ('A3EW2L59UBHQSG', 'Activision Anthology', 5.0),
#  ('A1BNJKGU3XTEBT', 'Black &amp; White - PC', 5.0),
#  ('A6QT2AWT17QAU', 'Borderlands 2 - PC', 5.0),
#  ('A136TNCSEGNU8R',
#   'The Sims 3: Fast Lane Stuff - Expansion  [Download]',
#   5.0),
#  ('A2VV6ELLW00FAW', 'LEGO Dimensions Starter Pack - Xbox One', 4.0),
#  ('A2G72CNDPE0SE6', 'Tokyo Mirage Sessions #FE - Wii U Standard Edition', 5.0),
#  ('A1MNQO0CD83W0J',
#   'Star Ocean: Integrity and Faithlessness - PlayStation 4',
#   3.0),
#  ('A1F9W4GK66NNYB', 'Killzone Mercenary', 5.0),
#  ('A10JFRVQCYQTP2', 'Batman: Arkham Knight - Windows Standard Edition', 4.0),
#  ('A1RUOIU1M5PS56', 'Borderlands: The Pre-Sequel - PC', 5.0),
#  ('A3CQ3FEN6IUIL0', 'Nyko Charge Station Quad for Wii (Black)', 5.0),
#  ('A266FSXW817ME9',
#   'EUASOO Mouse Mice Z-7900 4000 DPI Metal Base MMO/FPS High Precision Optical Gaming Mouse',
#   4.0),
#  ('AQMWZIH22R6LE', 'Yu-Gi-Oh! Duelists of the Roses', 4.0),
#  ('A11KJL9KEJ30OD', 'Headphone Audio Adapter for Xbox 360', 4.0),
#  ('A3JE3KOM53WUSJ', 'Neverwinter Nights Diamond', 3.0),
#  ('A26XIB9UGXJMNI', 'Railroad Tycoon 3 - PC', 2.0),
#  ('A2HAZQTH11RB37', 'MSI Gaming Headset with Microphone (DS501)', 2.0),
#  ('A1BG8BAGD66PRP', 'Xbox 360 Wireless Controller - Glossy Black', 5.0),
#  ('A2QKYG253CAS4Q', 'World of Warcraft - Mac / Windows XP / Mac OS X', 5.0),
#  ('A1KLMRTI7G5LJW', 'Xbox 360 Play &amp; Charge Kit', 5.0),
#  ('A38N3SA9Y2JIBU',
#   'PlayStation 4 Black Friday Bundle - Grand Theft Auto V and The Last of Us Remastered',
#   1.0),
#  ('A24OPOKX1WF16N', 'Far Cry 4 - Xbox 360', 5.0),
#  ('AGPUUK24YB6YL', 'Mall Tycoon - PC', 3.0),
#  ('A198SE1M7QB7LT',
#   'Gaming Mouse USB LED Gamer Mice 5500 DPI Professional Optical Wired 6 Buttons for PC Laptop',
#   5.0),
#  ('A3OY8HO3IU477L', 'Pitfall: The Lost Expedition', 5.0),
#  ('A1S503WZ2QLXLH', 'Rayman Legends - PlayStation 4 Standard Edition', 5.0),
#  ('A1NTS811TTHTLH',
#   'Forza Horizon 3 - Xbox One/Windows 10 [Digital Code]',
#   5.0),
#  ('A1OV3ZOK9IHRJS',
#   'SADES Stereo 7.1 Surround Pro USB Gaming Headset with Mic Headband Headphone (White)',
#   5.0),
#  ('AOSKM5QFUU0J2', "Mirror's Edge Catalyst Collector's Edition - PC", 2.0),
#  ('A2K210K757O28', 'Airdrop Gaming HipShotDot (HSD-1619)', 2.0),
#  ('AG1L795QJ5NHX', 'Bejeweled 2', 4.0),
#  ('A1WIPFB5388YG9', 'Monster Hunter - PlayStation 2', 5.0),
#  ('A2FKATJKLGYO5D', ' Gran Turismo 5 - Playstation 3', 2.0),
#  ('A3LAZSKALK8UOX', 'PlayStation Move Racing Wheel', 3.0),
#  ('A3CGRXVUH40NL5',
#   'Turtle Beach Call of Duty: Ghosts Ear Force Shadow Limited Edition Gaming Headset -Microsoft Xbox 360',
#   5.0),
#  ('AIIDX14T6BFVZ', 'Far Cry 3', 5.0),
#  ('A1PW1TJ6FD2I45', 'Nintendo GameCube Component Video Cable', 5.0),
#  ('A23FK3AAY2V58E', 'Xbox 360 Rock Band Special Edition', 5.0),
#  ('A2V47WC439UGB0',
#   'Thrustmaster VG Thrustmaster T500 F1 Racing Wheel - PC',
#   5.0),
#  ('A3TIULGRQN2HKL',
#   "Assassin's Creed Unity Limited Edition - PlayStation 4",
#   5.0),
#  ('A1DE34EAEKDGCB',
#   'Mcbazel PlayStation 2 Controller to USB Adapter for PC or Playstation 3 Converter Cable for Sony DualShock PS2 PS3 Controllers (NOT compatible with Dancing Mat Guitar Hero)',
#   4.0),
#  ('A1HE22G06HMLL4', "Five Nights at Freddy's [Download]", 5.0),
#  ('A1Y1MIA6650MAC',
#   'Gaming Keyboard and Mouse Sets - BAKTH 3 Cool Colors LED Backlit Wired USB Keyboard and Mouse Combo for PC Computer Games Including Durable Mouse Mat (Black)',
#   1.0),
#  ('A7F9NEQK9SBE2', 'The Sims 3 Starter Pack - PC/Mac', 5.0),
#  ('A3SNTQKTJ28XDJ', 'Beyond Good &amp; Evil', 5.0),
#  ('A20BDR5RJHE3Q4',
#   'SEMSA PUBG Mobile Game Controller &ndash; [New Version] Cell Phone Gaming Joystick Accessories, Gamepad, L1R1 Sensitive Shoot and Aim Triggers Fire Buttons for iOS Android (2 Trigger and Game Pad)',
#   5.0),
#  ('A1J3PZ1HDZ95YE',
#   'Cronusmax Plus with Bluetooth Dongle &amp; Sound Card - PlayStation 4',
#   5.0),
#  ('A1ECW3UN7ZKJ7U', 'Wheel of Fortune, Deluxe Edition', 3.0),
#  ('A3BGY3KDP7XP5V',
#   'USPRO PS3 Bluetooth 6 Axis Wireless Game Controller Gamepad Joypad Dualshock with Charging Cable for SONY Playstation 3',
#   5.0),
#  ('A2N1P8ODATT5PF',
#   'Old Skool AV CABLE GAME CUBE NINTENDO 64 SUPER NINTENDO (Bulk Packaging)',
#   4.0),
#  ('A19N698DWTYPHD', 'F1 2011 - Xbox 360', 3.0),
#  ('A3B5F3NH6F2SQE', 'Settlers II - 10th Anniversary Edition', 1.0),
#  ('AFN0AEQMEKQC3', 'Grand Theft Auto V - PlayStation 4', 5.0),
#  ('A2CVSIIBQFG2GC', 'Command &amp; Conquer', 5.0),
#  ('A2YKVMX0AV3QV8', 'Romania - Hidden Object Game [Download]', 2.0),
#  ('A2JKJGIA2E4UC9', 'Zoom for Kinect - Xbox 360', 1.0),
#  ('A23XDE090GPFWJ', "Age of Empires Collector's Edition - PC", 5.0),
#  ('ANAP6CHXLL226',
#   'Razer Ouroboros Elite Ambidextrous Wired or Wireless Gaming Mouse - 8200 DPI 4G Laser Sensor',
#   4.0),
#  ('A3HO98ANUJ31B5', 'Mortal Kombat: Komplete Edition - Xbox 360', 5.0),
#  ('A3DIMK33JFV9ER', 'Xbox Controller S-Blue', 3.0),
#  ('A3C8IUK92R6137', 'Heavy Rain - Greatest Hits', 2.0),
#  ('A1XEL2DYZT6SEY',
#   'Xbox One Chatpad + Chat Headset (plugs directly into Chatpad)',
#   4.0),
#  ('A3TE9XJEDWMFV9', 'God of War Origins Collection - Playstation 3', 5.0),
#  ('A2459P4ABDGYYN', 'Grand Theft Auto III', 5.0),
#  ('A1XF603EM1ZS0Y', 'Wireless Stereo Headset - Playstation 3', 5.0),
#  ('A251HZJ72Y4XPN', 'Star Fox Assault', 5.0),
#  ('A1UK11RXBS66CN', 'Wolfenstein: The New Order - PC', 4.0),
#  ('ABCF9FX5HVYA3', 'Medal of Honor Airborne - Xbox 360', 5.0),
#  ('A32WBVHUIFQD94',
#   'Evercool Defender Turbo Cooling Fan - Playstation 3 (Not compatible with PS3 Slim)',
#   4.0),
#  ('AQOBRN1FRX0IZ',
#   'Nancy Drew - Alibi in Ashes &amp; The Deadly Device 2-Pack (PC-DVD) (XP, VISTA, Windows 7, Windows 8) PC Detective Game',
#   5.0),
#  ('A38483U1Y2HV89',
#   'Turtle Beach - Ear Force PX22  - Universal Amplified Gaming Headset- PS3, Xbox 360, PC - FFP [Old Version]',
#   4.0),
#  ('A24QLA72AQUUP9',
#   'CM Storm Trigger - Mechanical Gaming Keyboard with CHERRY MX BROWN Switches and Fully LED Backlit',
#   5.0),
#  ('A2GP6MP0DXBSY1',
#   'Razer Kraken 7.1 Chroma Sound USB Gaming Headset - 7.1 Surround Sound with Retractable Digital Microphone and Chroma Lighting',
#   5.0),
#  ('A2DEIGOBHETAE5',
#   'GoldenDeal PS4 Console and DualShock 4 Controller Skin Set - Red Color - PlayStation 4 Vinyl Colour',
#   2.0),
#  ('A1SW80RQNB3DMK', 'Myth: The Fallen Lords - PC/Mac', 5.0),
#  ('A1X35E55EF7YTR', 'Steel Tide - PC', 4.0),
#  ('AOOCA0GY4FGNX', 'Pokemon - Diamond Version', 5.0),
#  ('A3QL8WRI4HFYVZ', ' Karaoke Revolution', 4.0),
#  ('A1CTZVV20T3QRZ', 'Fallout 4 - PlayStation 4', 5.0),
#  ('AVAMO0F7YO2HK', 'Nintendo DS Lite Polar White', 5.0),
#  ('A2696I6CZYNAGH',
#   'Nyan CYBER HACHI / silicon cover cat (for 3DS LL) tabby',
#   5.0),
#  ('A3HA6EIWGFJ7WZ', 'L. A. Noire', 5.0),
#  ('A3OUDMAZV0XHXL',
#   'Plantronics GAMECOM 818 Wireless Stereo Headset Extended Gaming Sessions PC, MAC Playstation 4',
#   1.0),
#  ('A3OF8LEFHO21Z8', 'The Last of Us Remastered - PlayStation 4', 5.0),
#  ('A9QWM838Q2O1U', 'Xbox 360 Pro 20 GB', 5.0),
#  ('A31RO7D1UCJHCZ', 'Life is Strange - Episode 1 [Online Game Code]', 5.0),
#  ('A9HO0721QCWSE', 'The Guild Complete Collection', 5.0),
#  ('A3IFQDCUNAAJQF', 'Middle Earth: Shadow of Mordor - PlayStation 3', 4.0),
#  ('A3HKMYIV113O2K', 'NBA 2K15 - Xbox One', 5.0),
#  ('ARHXE6SQZ1VT6',
#   'TeckNet Gaming Keyboard and Mouse Gryphon Pro LED Backlit Illuminated Programmable Mecha-Membrane Wired Gaming Mouse and Keyboard Set, Spill-Resistant Design, US Layout',
#   5.0),
#  ('A20JMYLJSS4ZUF', 'DuckTales - Remastered - Wii U', 5.0),
#  ('A2UT3YE6VJ03ER', 'Power Stand for Wii U', 5.0),
#  ('A1X8W8QDZ5LP9J', 'TrackIr 5 Premium Head Tracking for Gaming', 5.0),
#  ('A2FXUH07OCHF6R', 'Pokemon Gold', 3.0),
#  ('A2PRDB3P8LMAHO',
#   'Playstation Plus: 3 Month Membership [Digital Code]',
#   4.0),
#  ('A17J9MG8WMJ5NA', 'Bloodborne', 5.0),
#  ('A2RG3NQX2EWF1W', 'The Walking Dead: Season 2 - Xbox 360', 5.0),
#  ('A2P6M135RRV62R', 'Stuntman', 1.0),
#  ('ANX0QR90K1PDL', 'Fallout 3: Game of the Year Edition', 5.0),
#  ('A1V10X8NW3H7SW',
#   'Sades SA920 3.5mm Wired Stereo Gaming Over Ear Headset with Microphone and Revolution Volume Control for Xbox One / Xbox 360 / PS4 / PC /Cell phones / iPad (Black/White)',
#   5.0),
#  ('A1872EBRPA0EB0',
#   'Turtle Beach Ear Force XP SEVEN MLG Pro Circuit Programmable Surround Sound Console Headset',
#   3.0),
#  ('A1KZ13WVJAR9TJ', 'Need for Speed: Rivals', 3.0),
#  ('A2L6K9K6WLGL2N', 'Max Payne - PC', 5.0),
#  ('AQHA594K05VS6', 'Wild Earth: African Safari - Nintendo Wii', 1.0),
#  ('A3MBEIJRTDNZIM',
#   'Matricom G-Pad EX Wireless USB Rechargeable Pro Game Pad Joystick w/3D Feedback',
#   2.0),
#  ('A1B1IF06U4LHC1', 'FIFA 14 - Playstation 3', 3.0),
#  ('A2Q1OOILX7T9T4',
#   'Andoer Wired Nunchuck and Remote Controller with Motion Plus for Nintendo Wii With Retail Package (Red)',
#   4.0),
#  ('A2WSF7JUBSFR0U', 'Soul Calibur II - Gamecube', 5.0),
#  ('A2CQ3PARH3B4K5', 'Nyko Charge Base Power Plus PS4 (83208)', 5.0),
#  ('A1IALZT5NKM98E', 'Xbox One Wireless Controller [Without Bluetooth]', 5.0),
#  ('A2LOTWXOOIPANC', 'Datel Max XBOX Action Replay', 4.0),
#  ('AZFXNPGLMPS3V', 'The Sims 3 Starter Pack (Mac) [Online Game Code]', 1.0),
#  ('AKKSB4ZDJBEMX',
#   'Xbox 360 Modded Controller 10 Mode Rapid Fire Wireless with Red D-pad, Led, and Thumb Sticks for COD Advanced Warfare, Ghost, Mw3, Black Ops 2',
#   1.0),
#  ('AXGIOLZ06MLJ8', 'Metal Slug X', 5.0),
#  ('AIO78KOAFNGSS', 'The Legend of Zelda: The Wind Waker', 5.0),
#  ('AWII4D91U2U4J', 'PlayStation Eye', 1.0),
#  ('AN5IA5BOO9DP8', 'The Sims 2 Seasons Expansion Pack - Mac', 5.0),
#  ('A34KVLDA5H9JUP',
#   'Mayflash NES/SNES/FC/SFC Controller Adapter for Wii &amp; Wii U',
#   5.0),
#  ('A2V4VQEZJD5A8D', 'TrackMania Turbo - PlayStation 4', 5.0),
#  ('ADJBM7O5FFIV0',
#   'Sanwa GT-Y Octagonal Restrictor Plate for JLF Joysticks',
#   5.0),
#  ('A30JRMJ6PTLTXV', 'Dynasty Warriors 4 - PlayStation 2', 5.0),
#  ('A3RYJFDHMH19DB', 'The Sims 2: Apartment Life Expansion Pack', 3.0),
#  ('A2U9P5RPAY6GZK', "Mortal Kombat: Deception - Kollector's Edition", 1.0),
#  ('A1XXK0CX2TFGLY', 'CirKa Controller for N64 (Fire)', 5.0),
#  ('A2VE83MZF98ITY', 'Civilization II: Multiplayer Gold Edition', 5.0),
#  ('AJ6UWLWTPU4H9',
#   'Wolfgang - Nintendo Animal Crossing Happy Home Designer Amiibo Card - 255',
#   5.0),
#  ('A1BP6ITXXYMHQV', "The Legend of Zelda: Link's Awakening", 5.0),
#  ('AXN14S2HLATIK',
#   'BenQ Zowie ZA12 E-Sports Ambidextrous Optical Gaming Mouse',
#   4.0),
#  ('A3C5K3YZ8TOPFY',
#   'Nintendo Wii Intec G5614 Dual Charge Station and Turbo Cooler',
#   4.0),
#  ('A1DSBJDRJKL5JF', 'Logitech G700s Rechargeable Gaming Mouse', 5.0),
#  ('A15PIIRCGUT35J',
#   'BlackZone Controllers&copy; - (PS4 Pro Newest Revision) PS4 Modded, COD WWII, RAPID FIRE Jump Shot, Drop Shot, BURST, Quick Scope, Sniper Burst, Auto Aim, Auto RUN, Modified for COD and many others.',
#   5.0),
#  ('A11EBKU9HXE4RE',
#   'Logitech G502 Proteus Spectrum RGB Tunable Gaming Mouse, 12,000 DPI On-The-Fly DPI Shifting, Personalized Weight and Balance Tuning with (5) 3.6g Weights, 11 Programmable Buttons',
#   5.0),
#  ('A22TU5I31360L9', 'Rayman 2: Revolution', 3.0),
#  ('A27Q6MKZX1H00', 'Gamecube Memory Card 251', 5.0),
#  ('A21J5X6RCEXA6F', 'Bravely Default - Nintendo 3DS', 1.0),
#  ('A3NG0CLJRZT33N', 'Wild Arms 3 - PlayStation 2', 5.0),
#  ('A2HPZHIQN696W', 'TMNT - Xbox 360', 5.0),
#  ('A3QWJC38WSA3QL', 'Plantronics GameCom 367 Closed-Ear Gaming Headset', 3.0),
#  ('A2F1CR0KVNOO9J', 'NASCAR Racing: 2002 Season - PC', 5.0),
#  ('A3U8AD9TII1DXY',
#   "Green Yarn Yoshi amiibo - Japan Import (Yoshi's Woolly World Series)",
#   5.0),
#  ('AMR0H8AG7HUZ7', 'Battlefield 1 - Xbox One', 5.0),
#  ('A2T7H9U0PYPO6I', 'Thief Gold [Download]', 5.0),
#  ('A3NDB4MMNFKAQP', 'Mega Man Anniversary Collection - Gamecube', 5.0),
#  ('AAW0T1BP1E33H',
#   'Corsair Vengeance K70 Black Cherry MX Brown (CH-9000067-NA)',
#   5.0),
#  ('A191KJLTRKR47R', 'Dirt Track Racing 2 - PC', 5.0),
#  ('AM70V6CLLRVKU', 'Sonic Adventure 2 Battle - GameCube', 5.0),
#  ('A28Y93F011SMON', 'Halo - Xbox', 4.0),
#  ('A2BDDXDLQ2I6AM', 'Wireless Keyboard and Mouse', 5.0),
#  ('A1VZNDUDHPF8P1', 'PlayStation 4 DualShock 4 Bundle [Discontinued]', 1.0),
#  ('A1EE2XJ9S9403D', "Tom Clancy's Rainbow Six 3: Raven Shield - PC", 5.0),
#  ('AR2UQW6JTEF8T', 'PlayStation 2 Dualshock Controller Black', 2.0),
#  ('A3UH0RAEY0S9ZI',
#   'Havit Rainbow Backlit Wired Gaming Keyboard Mouse Combo (White)',
#   4.0),
#  ('A2F0AOO92JPFW5', 'Nintendo Wii Remote Plus - Blue', 5.0),
#  ('A1O66ZDPQ5FEXL', 'Dotop Sony Playstation 2 PS2 64MB Memory Card', 5.0),
#  ('A398DTIZ2HG95G', 'Magic The Gathering Online - PC', 5.0),
#  ('AN3NLOTAEJKPQ', 'Fate 1 2 3 Jewel Case', 3.0),
#  ('AGHDTW943QOC0',
#   'Old Skool Classic Wired Controller Joystick for Nintendo 64 N64 Game System - Green',
#   2.0),
#  ('A2H8ZYB77C1EVT', '4x Wii/Gamecube Extension Cables', 3.0),
#  ('A2566NSBE138RW', 'Guild Wars Game of the Year - PC', 1.0),
#  ('A2W47MSFHLX5U4', 'Binary Domain - Playstation 3', 3.0),
#  ('A5P758ZPRR3I', 'Train Simulator - PC', 1.0),
#  ('ADR621ADB516R',
#   'Etrian Odyssey Untold: The Millennium Girl - Nintendo 3DS',
#   5.0),
#  ('A1JZUKCXVEI8ED',
#   'Xbox One Play Charge Kit- 1600mAh Xbox One Rechargeable Battery Pack for Wireless Controller w/ USB Charging Cable',
#   3.0),
#  ('AUZD2I72S2UJL', 'Galactic Civilizations II Ultimate Edition - PC', 1.0),
#  ('AB35OH1HHZC99', ' Guild Wars 2', 5.0),
#  ('A2AUWHWV97OXV4', 'Minute to Win It (Kinect) - Xbox 360', 4.0),
#  ('AH5NJ6TC75I5D', 'Forza Motorsport 5', 5.0),
#  ('A7XFKGC4ZWIAB', 'Wii Party U', 2.0),
#  ('A15AJWTKTQL75O', 'Dokapon Kingdom - Nintendo Wii', 5.0),
#  ('ARYPHBI97NXO3', 'Ratchet &amp; Clank Collection', 1.0),
#  ('A2R0064SAE50DS', 'Playstation 3 HD Component Cable', 1.0),
#  ('AL0RF1GSI5DAQ', 'Donkey Kong Country Returns', 3.0),
#  ('A10YNQ7SPY4X63',
#   'Konami Karaoke Revolution Presents: American Idol Encore Game Only',
#   5.0),
#  ('A3JJBOXNP7TCZ9',
#   'Dark Pit amiibo - Japan Import (Super Smash Bros Series)',
#   5.0),
#  ('A1PP1SEVPTF9HI',
#   'SquidGrip for Xbox 360 Controller (Controller Not Included)',
#   2.0),
#  ('A1XBVQELHUJG91',
#   'dreamGEAR Comfort GRIP Protection for your NEW Nintendo 3DS XL',
#   3.0),
#  ('A1KRBGN92XEKN8', 'UFO Trilogy [Download]', 4.0),
#  ('A8DJ4WKJJ8T4J', 'Grand Theft Auto: Vice City - PC', 5.0),
#  ('A2TRG6417T7VBM', 'Major League Baseball 2K11 - Xbox 360', 1.0),
#  ('AUHM9N7RMF2E7', 'Grand Theft Auto V - Xbox 360', 5.0),
#  ('A3D7U0X2TQ57S8',
#   'Sonic amiibo - Japan Import (Super Smash Bros Series)',
#   5.0),
#  ('A178R0T246JXZT', 'Unreal Tournament 2004', 5.0),
#  ('A37014KFCFNGM0', 'Monopoly', 4.0),
#  ('A39DRGHQ7SFLOY', 'Godzilla - PlayStation 4', 5.0),
#  ('A21B5GIJEJDQN0', 'Middle Earth: Shadow of Mordor - PlayStation 4', 3.0),
#  ('A3D7OOFCKHZJJ1',
#   'Arc the Lad Twilight of the Spirits - PlayStation 2',
#   3.0),
#  ('A3NRZYJQEDD9DE',
#   'Corsair Gaming M65 FPS Gaming Mouse, Aircraft-Grade Aluminum, 8200 DPI',
#   1.0),
#  ('A3KI73MFVL0QWH',
#   'Return to Castle Wolfenstein: Operation Resurrection - PlayStation 2',
#   5.0),
#  ('A156RPVQEF3QMT', 'Namco Museum', 5.0),
#  ('AT576Z9DC6HJ0', 'Xenosaga - PlayStation 2', 5.0),
#  ('AWHHF8OK1IOQB', 'WWE 2K15 - PlayStation 4', 5.0),
#  ('A19KZL3C8E49VF', ' My Fitness Coach - Nintendo Wii', 5.0),
#  ('AQ9AF8PQ7Y61S',
#   'TeckNet Wired Gaming Mouse, Ergonomic Optical USB Gaming Mouse for Laptop PC Computer Gamer, Adjustable DPI Levels, 6 Buttons',
#   5.0),
#  ('A2P45DTP142S94',
#   'Sony PlayStation 3 Dualshock 3 Wireless Controller - White',
#   1.0),
#  ('AQNYG6U2WSEXO',
#   'GW SADES SA905 Wired USB PC Gaming Headset Over-Ear headband Headphones with Microphone Vibration LED Lights(Black&amp;White)',
#   5.0),
#  ('AFNVAJ1FGNUP',
#   'GoldenDeal Xbox One Dual Controller Stand Charger Dock Base w/ Extra Batteries - Charging Station',
#   5.0),
#  ('A23R87C760S5U3', 'Super Smash Bros. - Nintendo Wii U', 5.0),
#  ('A365XETY5ZX1VZ',
#   'Logitech G9X Programmable Laser Gaming Mouse with Precision Grips',
#   5.0),
#  ('A3NWDVRYFBV72W', 'Halo 3 - Xbox 360', 4.0),
#  ('AEG6TKXFVH0S3', 'NBA 2K16 - 15,000 VC - PlayStation 4 [Digital Code]', 1.0),
#  ('A2G47I8QPS99XH', 'Xbox One + Kinect', 5.0),
#  ('A1U36YAGMAQHVE', '32GB PlayStation Vita Memory Card', 5.0),
#  ('A1OU3WYAM16HP8', 'Cooking Mama 2: Dinner With Friends - Nintendo DS', 4.0),
#  ('A25Z9O9N9BUPI7', 'Brink', 2.0),
#  ('A2VTGQTAA1QGS0', '4x Wii/Gamecube Extension Cables', 5.0),
#  ('A36D2JJR7KK5VL', 'Need for Speed: Nitro', 5.0),
#  ('A3PSUT0B3QBND5', 'Sins of a Solar Empire Collectors Edition - PC', 4.0),
#  ('A3MMSU6OX5SVIQ', 'Disgaea 5: Alliance of Vengeance - PlayStation 4', 5.0),
#  ('A1CIWG45W8Z92K',
#   'Playstation Plus: 3 Month Membership [Digital Code]',
#   5.0),
#  ('A1T5FIQEX3NSVA', 'Dragon Age: Origins Awakening - Xbox 360', 5.0),
#  ('A2AURSJFER6YGD', 'Halo 4: Game of the Year Edition', 5.0),
#  ('A1X3PMO4VD2CQQ',
#   'Anrain Dual PS4/PS4 Slim/PS4 Pro Gaming Controller LED Charging Stand USB Charger Dock Station Cradle For Sony Playstation 4 PS4 / PS4 Slim /PS4 Pro',
#   5.0),
#  ('A2UJKL6DFPRG7M',
#   'Findway&reg; Wired USB Controller for PC &amp; Xbox 360 (Black)',
#   3.0),
#  ('ABA6AP00U1SCE',
#   'Nintendo Wii U Deluxe Set: Super Mario Bros U &amp; Luigi U (32 GB)',
#   5.0),
#  ('A3HNMKMU0YJAN7', 'Razer Nostromo PC Gaming Keypad', 5.0),
#  ('AUNM3BLNWRH3J',
#   'Skylanders Giants: Single Character Pack Core Series 2 Stump Smash',
#   5.0),
#  ('A5MFB9YPWOE7', 'Xbox 360 250GB Console', 5.0),
#  ('A6M5CO31EGJNL', 'Xbox One Chat Headset', 2.0),
#  ('AGBPZ6WCXSXL5',
#   'Turtle Beach Ear Force Z Seven Tournament Series Headset',
#   1.0),
#  ('AITIFHS7Q46A7', 'Dead Or Alive Xtreme 2', 3.0),
#  ('ATQG89H2G4I7R',
#   'PS4 Designer Skin for Sony PlayStation 4 Console System plus Two(2) Decals for: PS4 Dualshock Controller - Mandy Black',
#   5.0),
#  ('A3TM8LLDXSKKRY', 'The Da Vinci Code - PC', 3.0),
#  ('AN92AQ65HXPJ3', 'The Legend of Zelda: Twilight Princess', 5.0),
#  ('A2EVITK1SQY1GZ', 'Pac-Man Vs. / Pac-Man World 2', 3.0),
#  ('A3OM94ZYBX22G1', 'Warhammer Dawn Of War Platinum - PC', 4.0),
#  ('A32EQ5RPTY72HZ', 'Fallout 4 - Xbox One', 4.0),
#  ('A1SBKXIF5X5P58', 'Final Fantasy III', 5.0),
#  ('A17TQYKJFNCUIB',
#   'Xbox One Wireless Controller (Without 3.5 millimeter headset jack)',
#   5.0),
#  ('A247VET7CP4K7J', 'Lego Star Wars: The Complete Saga - Xbox 360', 5.0),
#  ('AWRLUL9AGRKZV',
#   'Logitech G9X Programmable Laser Gaming Mouse with Precision Grips',
#   5.0),
#  ('A1X47TB4TW6UD6',
#   'Bowser amiibo - Japan Import (Super Smash Bros Series)',
#   5.0),
#  ('A1T59BV9U4NO36',
#   'PS3 250GB Amazon Exclusive Family Entertainment Bundle',
#   4.0),
#  ('A19R6YHSWTL65C',
#   'Gaming Headset for PS4 Xbox one Nintendo Switch, TUSBIKO Gaming Headphones with Noise Cancelling Microphone, Bass Surround Sound Over Ear Wired Headset LED Lights (RGB)',
#   5.0),
#  ('A29KXZ2MU16HMR',
#   'Thrustmaster Ferrari Racing Wheel Red Legend Edition (PC/PS3)',
#   2.0),
#  ('AOQ2IB802NXAQ',
#   'My Little Pony Friendship is Magic Princess Decorative Video Game Decal Cover Skin Protector for Nintendo 2Ds',
#   4.0),
#  ('A2SAX9SWAS1YO3', "PGA Championship Golf: Collector's Edition", 5.0),
#  ('A2SSPOTYV7CMWI', '$10 PlayStation Store Gift Card [Digital Code]', 5.0),
#  ('A2U6ISFMYBEYIJ', 'Splatoon 3-pack amiibo (Splatoon Series)', 5.0),
#  ('A2O6B2U02RQB1X', 'The Legend of Zelda - Classic NES Series', 4.0),
#  ('A17LY4Y2IW1XB3', 'Country Dance Kinect - Xbox 360', 5.0),
#  ('A1P0JSFW184ZXJ',
#   'SteelSeries Stratus XL Bluetooth Wireless Gaming Controller for iOS Devices(69026)',
#   5.0),
#  ('AGX44HTFD2SBF', 'Hunting Unlimited 2009 - PC', 1.0),
#  ('AR4RB6KX9X31A',
#   'Everquest Online Adventures: Frontiers - PlayStation 2',
#   5.0),
#  ('A25KW7SOA78XAQ', 'NBA Jam T.E. Tournament Edition', 4.0),
#  ('A2AX997PT3Y0Z3',
#   'Xbox One 500GB Console with Kinect Bundle (Includes Chat Headset)',
#   5.0),
#  ('A3V31Q0WOCLL1D', 'Nintendo Wii Remote Plus - White', 5.0),
#  ('A1GCZFPD34TLOS',
#   'GameSir G3w USB Wired PC Game Controller Dual Shock Joystick Gamepad for PC Windows 7/8/8.1/10 &amp; Android Smartphone/Tablet/TV BOX &amp; PS3',
#   5.0),
#  ('A30ZJ01FS6H1KP', 'Resident Evil 4 - Gamecube', 5.0),
#  ('A37M177YIGZGDW', 'Final Fantasy X', 5.0),
#  ('AJ5O13UGW4T47', 'MX vs ATV Unleashed - PlayStation 2', 4.0),
#  ('A1NY16715ACM94', 'Rock Band 4 Wireless Guitar Bundle- Xbox One', 4.0),
#  ('A2FRGWR146MYKK', "Cruis'n World", 4.0),
#  ('A2KUI3UMVXXTSP', 'Super Mario Bros.', 5.0),
#  ('A321W4SSC0F6AP', 'Family Game Pack 2001', 3.0),
#  ('AAQQW4GVY7H58', 'Battlefield 4 - Xbox One', 5.0),
#  ('A1Y1QJ06XNWPVJ', 'Uru: Ages Beyond Myst - PC', 2.0),
#  ('A1J2TTM53YSE19', 'Gex', 4.0),
#  ('A296C7J1M7BG7G', "Luigi's Mansion - Gamecube", 5.0),
#  ('A38B96V0HUHMT9', ' My Fitness Coach - Nintendo Wii', 3.0),
#  ('A15GH2K6B6CLWH',
#   'Harry Potter and the Prisoner of Azkaban - PlayStation 2',
#   5.0),
#  ('A3UMO6QMSI2DK9',
#   'Turtle Beach - Ear Force Recon 50P Stereo Gaming Headset - PS4 and Xbox One (compatible w/ Xbox One controller w/ 3.5mm headset jack)',
#   5.0),
#  ('AV96YW1J50XJ1',
#   'Casino Express &quot;Maglev 2005&quot;: add-on for Microsoft Train Simulator',
#   2.0),
#  ('A2A5K9A8YH3TTH', ' Universal PS2 to PS3 Controller Adaptor', 5.0),
#  ('A1TKL5QSWKYTN6',
#   'CH Products Pro Pedals USB Flight Simulator Pedals (300-111)',
#   5.0),
#  ('A1UHQVIID1SCJK', 'Jagged Alliance 2 - PC', 5.0),
#  ('A2V8BO8DWSB7QO',
#   'Xbox One Wireless Controller (Without 3.5 millimeter headset jack)',
#   5.0),
#  ('A2RYZRAIF0R03J',
#   'The Elder Scrolls V: Skyrim Special Edition - PS4 [Digital Code]',
#   5.0),
#  ('AL5BNLXK7NS4', 'Splatoon 3-pack amiibo (Splatoon Series)', 5.0),
#  ('A357NYGGKQFGU7', 'Nintendo 64 System - Video Game Console', 1.0),
#  ('A5JZ380CDEKWB', 'Need for Speed Hot Pursuit - Playstation 3', 5.0),
#  ('A552GU6AZ38WA',
#   'EA Sports Active 2 Weighted Workout Boxing Gloves EA212-FR',
#   2.0),
#  ('AFIX233T7N4MX', 'Teenage Mutant Ninja Turtles', 5.0),
#  ('A4G1Q8CR5G4VN',
#   'Sid Meiers Civilization IV: The Complete Edition - PC',
#   5.0),
#  ('A1AFIS1ZS8NWOR', 'Nintendo DSi XL - Midnight Blue', 5.0),
#  ('A1M1MJBMJDKEYU', 'Logitech G700s Rechargeable Gaming Mouse', 5.0),
#  ('A3JHQY01OLSLZR', 'The Sum of All Fears - PC', 3.0),
#  ('A3MDL4OL3WQW0Z',
#   'Playstation Plus: 3 Month Membership [Digital Code]',
#   5.0),
#  ('A35M10SZQI4CNP',
#   'Need for Speed Rivals (Complete Edition) - PlayStation 3',
#   5.0),
#  ('A1QYN3YYQV7YGE', 'Playstation 2 Console - Black', 5.0),
#  ('A7GNI03PKUQJ3',
#   'Official Microsoft Xbox 360 SLIM Power Supply AC Adapter  (Bulk Packaging)',
#   1.0),
#  ('A2CJA2D9QB5N8N',
#   'PlayStation 4 500GB Console - Call of Duty Black Ops III Bundle [Discontinued]',
#   5.0),
#  ('A2FIZSSZZGGCJN', 'Battlefield 1 - Xbox One', 5.0),
#  ('A34WL7KYUUQXFW',
#   "Razer DeathAdder Chroma - Multi-Color Ergonomic Gaming Mouse - 10,000 DPI Sensor - Comfortable Grip - World's Most Popular Gaming Mouse",
#   5.0),
#  ('A3SSMLMEZYXSH7', 'NASCAR Dirt to Daytona', 4.0),
#  ('A3ETHD3C7G1RSD',
#   'Matricom G-Pad XYBA Wireless Rechargeable Bluetooth Pro Game Pad Joystick Controller (Samsung Gear VR, PC, PS3, and G-Box Compatible!)',
#   5.0),
#  ('A4CNLZGR3NM23', 'Legend of Mana', 1.0),
#  ('A3QHPFEWADUULZ', 'F-Zero X', 4.0),
#  ('A2GZQTQ7RDLBUI', 'The Sims 3 Seasons [Online Game Code]', 5.0),
#  ('A1GI8LZO5V0L5M',
#   'Razer Firefly Chroma Hard: Micro-Textured Finish - Non-Slip Rubber Base - Powered by Razer Chroma - Hard Gaming Mouse Mat - RZ02-01350100-R3U1',
#   5.0),
#  ('AR93F5ZX4KNLE',
#   'Generic Sony PlayStation 3 Slim Edition AC Power Adapter Cord Bulk',
#   5.0),
#  ('A1DK1JK7EHCNCE', 'Battlefield 4 [Online Game Code]', 5.0),
#  ('A3MLTFCMZTJTE3', 'Command and Conquer The Ultimate Collection', 1.0),
#  ('A382D7SRLXDECQ', 'Unreal Tournament - PlayStation 2', 2.0),
#  ('A3I8WVS7VMPK8I', "Hoyle Texas Hold 'Em Poker (Jewel Case)", 5.0),
#  ('A1A41XZYDQV56',
#   'GW SADES SA708 3.5mm Surround Sound Wired Over-the-Ear Gaming Headset with Microphone (Yellow)',
#   1.0),
#  ('A30DU0W4TMEZZH',
#   ' Dual Pack Guitar Hero III and Guitar Hero Aerosmith - Nintendo Wii',
#   5.0),
#  ('AL595BBGO5SGW',
#   "Assassin's Creed IV Black Flag: Season Pass - PS3/ PS4 [Digital Code]",
#   5.0),
#  ('AAOQ0Q0CFBPX1', 'Nyko Net Connect for Wii', 5.0),
#  ('AY377UZCPB4WG', 'BioShock Infinite [Download]', 5.0),
#  ('A2CGERTHPPIM76',
#   'HyperX Cloud II Gaming Headset - 7.1 Surround Sound - Memory Foam Ear Pads - Durable Aluminum Frame - Works with PC, PS4, PS4 PRO, Xbox One, Xbox One S - Gun Metal (KHX-HSCP-GM)',
#   5.0),
#  ('A2ERFGMJH41TRE', 'Xbox One + Kinect', 5.0),
#  ('A2FPFM588628DO', 'Fallout', 4.0),
#  ('AILB6NRZZMZF8',
#   '1 Pair of Bi-Convex Biconvex Lens Set 25mm Diameter 45mm Focal Length for Google Cardboard',
#   5.0),
#  ('A3W3NZAV0L5SDO', 'NBA 2K17 - Early Tip Off Edition - Xbox 360', 4.0),
#  ('AVY32ZTS1CM3T', 'BEYOND: Two Souls', 5.0),
#  ('A2K6B0ALIIQC8A',
#   'AceShot Thumb Grips (8pc) for Xbox One (One S &amp; X) by Foamy Lizard &reg; Sweat Free 100% Silicone Precision Raised Antislip Rubber Analog Stick Grips For Xbox One Controller (8 grips) BLACK',
#   3.0),
#  ('A2K8SIE85F3JID', 'PDP PSVita Nerf Armor - Purple', 5.0),
#  ('A1448ZDZCHMNME',
#   'The Elder Scrolls V: Skyrim - Legendary Edition, XBOX 360',
#   5.0),
#  ('A23PEUMC7ZGW5P', 'Fighter Within', 5.0),
#  ('A2GYN0J872XW88', 'Spore - PC/Mac', 1.0),
#  ('A1BX1EKKP97JUS', 'Just Dance 2015 - Xbox One', 4.0),
#  ('A1YAXKQKTUYMY0',
#   'Nyko Modular Charge Station (New Version) Dual Port Controller Charging Station with Patented Charging Dongles for All PS4 , PS4 Slim and PS4 Pro',
#   4.0),
#  ('AFRUWB2PG9CD9', 'Madden NFL 08 [Download]', 5.0),
#  ('A1GRAU0L22U1S4', "Assassin's Creed Unity - Xbox One", 5.0),
#  ('A2FKVV1RLCRHAY', 'PlayStation 2 Console (Slim Line Version 1)', 4.0),
#  ('A1K6J3J2N92TAP', 'Dragon Age 2 - Bioware Signature Edition - PC', 2.0),
#  ('AHCN4YZPC3U76', 'Datel Action Replay Power Saves Pro - Nintendo 3Ds', 5.0),
#  ('A33NFTU2K1SBYX', 'The Sims 2 University Expansion Pack - PC', 1.0),
#  ('A2K4VKM7ZEXQWX',
#   'Corsair Gaming K70 RGB Mechanical Keyboard, Backlit RGB LED, Cherry MX Red',
#   5.0),
#  ('A1Y3AFKSXAB8R8', 'Donkey Konga (includes Bongos)', 4.0),
#  ('A1GNV07W2DR6XN', ' Halo 3', 4.0),
#  ('A8GHS5DJ5G1GI', 'NCAA Football 2003', 5.0),
#  ('A229IFOY1QMJVM',
#   'Perixx MX-2000 IIR, Programmable Gaming Laser Mouse - Red - 8 Programmable Button - Weight Tuning Cartridge - Avago 5600DPI ADNS-9500 Laser Sensor',
#   5.0),
#  ('A1RXZ2YDGBJLA7', 'Rock Band 4 Pro-Cymbals Expansion Drum Kit', 5.0),
#  ('A2TUF9VOTO5WXS', 'Metroid', 4.0),
#  ('A9U62RQLHIWJ4',
#   ' SteelSeries Siberia v2 Full-Size Gaming Headset (White)',
#   5.0),
#  ('A3I98RAQXZ6H75',
#   "Uncharted 4: A Thief's End Libertalia Collector's Edition - PlayStation 4",
#   5.0),
#  ('A2XP4ME76TCA1U',
#   'WOVTE Nunchuk Controller for Nintendo Wii Wii U Video Game Black',
#   1.0),
#  ('A2S5YMO1T3N1KO', 'Xbox 360 AV Cable', 1.0),
#  ('A39ITG7ZEW4D12', 'Ace Attorney Investigations: Miles Edgeworth', 5.0),
#  ('A3Q09EE1RC4DY8',
#   'Pinball Hall of Fame The Gottlieb Collection - PlayStation 2',
#   4.0),
#  ('A33H2ZNN1WMAI5',
#   "Tom Clancy's Splinter Cell - PlayStation 2 (Jewel case)",
#   4.0),
#  ('AMML0047HULT8',
#   "PS3 Skylanders Spyro's Adventure LOOSE Portal of Power (Includes USB Receiver)",
#   5.0),
#  ('A25Y74DBZ5BHBL', 'Nyko 80610 AirFlo PC Game Controller', 1.0),
#  ('A16GF8CPAOG1HO',
#   "Assassin's Creed: Syndicate - Standard Edition - PlayStation 4",
#   1.0),
#  ('A28XGB7Q3A8VAQ', 'Word Slinger [Download]', 5.0),
#  ('A1JHD3VBMD8Q6C',
#   'NoScope Minotaur Yellow Lens Video Game Gaming TV &amp; Computer Glasses | Anti Blue Rays &amp; Glare Free | Eye Protection | Reduce Eye Strain and Fatigue | PS4 &amp; Xbox One - Polycarbonate Frame, Frost White',
#   5.0),
#  ('A2OK2ANHA6R0GA', 'Play It Loud Nintendo Game Boy Clear', 5.0),
#  ('A3QT9XXGQ80LYW', 'Fallout 4: Automatron - PS4 [Digital Code]', 2.0),
#  ('AX3F250TVOUF8',
#   'Final Fantasy X X-2 HD Remaster  Standard Edition - PlayStation 3',
#   5.0),
#  ('AZR2XCO2O7T7J',
#   'KontrolFreek Ultra Performance Thumbsticks for PlayStation 4 Controller (PS4)',
#   3.0),
#  ('A8HDB5BM3PUL',
#   'Corsair Gaming H2100 Dolby 7.1 Wireless Gaming Headset (CA-9011127-NA)',
#   5.0),
#  ('A715ULR66KDA2', 'FINAL FANTASY XIV [Download]', 1.0),
#  ('A33AJLNZ1CLZU3', "Assassin's Creed", 5.0),
#  ('A8JORWATI0UTH', "Assassin's Creed IV Black Flag - Xbox 360", 5.0),
#  ('AFDZWHH1A5NWI', 'Tiny Troopers [Download]', 3.0),
#  ('A3NYRIMIIXF6G2', 'Mario Paint', 5.0),
#  ('A38CFPZZMJDDCW', 'Wired USB Controller for PC &amp; Xbox 360 (Black)', 5.0),
#  ('A3BJQHVF5Y1OO8',
#   'Villager amiibo - Japan Import (Super Smash Bros Series)',
#   5.0),
#  ('A1J5FM2ARZVQ3O', 'Dave Mirra Freestyle BMX [PlayStation]', 4.0),
#  ('ACFNSEMUJJLSU',
#   'Power Supply Convert Adapter Cable for Xbox 360 Slim',
#   3.0),
#  ('A1VZYVPDNRK3Z3', 'Resident Evil: Survivor', 5.0),
#  ('AQPJJA7DUE3SL',
#   'Nyko Power Grip for Vita - PlayStation Vita 1000 series',
#   3.0),
#  ('AH5QSLH9YL61C', 'Playstation 2 Console - Black', 5.0),
#  ('AXLYF3IPB8XC7', 'Forza Motorsport 4 - Xbox 360', 5.0),
#  ('A2GSZRR85PC20N',
#   'The Elder Scrolls III: Morrowind Game of the Year Edition',
#   5.0),
#  ('A12MEA2KNBM7U2',
#   'HDE 128MB (2048 Blocks) Black Memory Card for Nintendo Gamecube or Wii',
#   5.0),
#  ('A33S79GE0NQAP', 'Wii Dancing Mat', 1.0),
#  ('A1I54MMN2FRWP1', 'Jeopardy Super Deluxe', 5.0),
#  ('A3AUW6G567BN65',
#   'The Witcher 3: Wild Hunt - Expansion Pass - Xbox One Digital Code',
#   5.0),
#  ('A3E6DJHNJ3WV', 'Frogger: The Great Quest - PC (Jewel case)', 1.0),
#  ('A2IA9T8LF2X5ZO',
#   'Disney Infinity 2.0 Marvel Super Heroes PS3 Replacement Game Only - No Base or Figures Included',
#   5.0),
#  ('A33X49EE652N2Z',
#   'Trenro AV to RCA Cable Compatible with Playstation/PS2/PS3/PSX',
#   5.0),
#  ('A1SEZBNT5DJRU1', 'Far Cry 4 - PlayStation 4', 5.0),
#  ('AIAITC52FTIKR',
#   'The Elder Scrolls IV: Oblivion Game of the Year Edition - PC',
#   5.0),
#  ('A38D7JJE3CGOXJ', 'Horizon Zero Dawn - PlayStation 4', 5.0),
#  ('A2ZFYB6WY3RG93', 'Sonic the Hedgehog - Sega Game Gear', 5.0),
#  ('A1F9QTVZL4WD9R', 'Battlefield 3 [Download]', 4.0),
#  ('A2TAF0MQ24MW2Q',
#   'HAVIT HV-MS672 3200DPI Wired Mouse, 4 Adjustable DPI Levels, 800/1200/2400/3200DPI, 7 Circular &amp; Breathing LED Light, 6 Buttons (Black)(Updated Version)',
#   4.0),
#  ('A2WN6QZU8KCLGJ',
#   'SADES Stereo Gaming Headphone with Microphone, Blue (SA-708 GT)',
#   1.0),
#  ('A3FUZCWNC6U8NS', 'Marvel&rsquo;s Spider-Man - PlayStation 4', 5.0),
#  ('A1M7EOOB2OW1MI',
#   'AULA Reaper Mechanical Gaming Keyboard with Blue Switches,Rainbow LED Backlight,104 Keys Anti-ghosting (Silver White)',
#   5.0),
#  ('A1NRRFKIX538MN', 'Razer BlackWidow Mechanical PC Gaming Keyboard', 1.0),
#  ('A2RO1QOHMK10KJ',
#   'Sades&reg; SADES Professional USB PC Gaming Headset with Mic &amp; Remoter (SA-901 Black + Red)',
#   5.0),
#  ('A33COX6ZNQEARY', 'Guitar Hero III: Legends of Rock Bundle', 5.0),
#  ('A12NXR35KBAAMV',
#   'Insten Wii controller wrist straps X 4 Compatible With WIIMOTE CONTROL',
#   5.0),
#  ('ASKAJHL3BDQWU', 'Mario Kart Wii with Wii Wheel', 4.0),
#  ('A2DKL2UDOM8RUM', 'Tomee AV Cable for PS3/ PS2/ PS1', 5.0),
#  ('A1A0BFCPDI9UKJ', 'Borderlands: The Handsome Collection - Xbox One', 1.0),
#  ('AJ7VJROR4Q8Q0',
#   'DualShock 4 Wireless Controller for PlayStation 4 - Soft Touch Blue PS4 - Added Grip for Long Gaming Sessions - Multiple Colors Available',
#   5.0),
#  ('A3BGP4SRW3VIEN',
#   'BMOUO 3.5mm Stereo Gaming Headset LED Lighting Over-Ear Headphone with Mic for PC Computer Game With Noise Cancelling &amp; Volume Control, Blue (G2000)',
#   5.0),
#  ('AJ7VVCALVT8KP', 'Nintendo Selects: Super Mario All-Stars', 5.0),
#  ('A2A4O8P6M6L5C8',
#   'CM Storm Spawn - Gaming Mouse with 3500 DPI Optical Sensor and Omron Micro Switches',
#   4.0),
#  ('A9HM9SQ06D1VZ',
#   'HDE Silicone Skin for Xbox 360 Controllers Rubberized Protective Cover for Microsoft Xbox 360 Wired and Wireless Gamepads (Green)',
#   4.0),
#  ('A2AU2BQAXAHR94', 'Gamecube Memory Card 59', 3.0),
#  ('A3E5TAC7P7GBNU', 'Carnivores: Cityscape - PC', 5.0),
#  ('A1EJERY2W54N86',
#   'Puzzle &amp; Dragons Z + Puzzle &amp; Dragons Super Mario Bros. - Nintendo 3DS',
#   4.0),
#  ('A33V25KHAU1SP7', 'Halo 2 - PC', 4.0),
#  ('A2J6D6D0NB1G44', 'Mortal Kombat Deadly Alliance', 2.0),
#  ('A3LHS5I7FZK5FF',
#   'Zacro PS4 Vertical Stand Cooling Fan Dual Charging Station for Playstation 4 Dual Shock 4 Controllers, with Dual USB HUB Charger Ports -Dual Use with Cooling and Charging System(Not for PS4 Slim/Pro)',
#   3.0),
#  ('AFBKV9OAKM9RD', 'Mamas &amp; Papas Soft Toy, Peanut Elephant', 5.0),
#  ('A35107XB86H392', "Dante's Inferno Divine Edition - Playstation 3", 5.0),
#  ('A3H04M0RPD0T3H', 'PS2 Memory Card (8 MB)', 1.0),
#  ('A14FRR8LRJR51W',
#   'Sades_equips Sades 708 Zombie Version Stereo Headphone Computer Gaming Headset Microphone',
#   5.0),
#  ('A1I15H481JHDH7', 'Yoshi amiibo (Super Smash Bros Series)', 5.0),
#  ('A1VREL2LDWGXRG', 'Major League Baseball 2K12 - Playstation 3', 5.0),
#  ('A1RHEPBF3ZW6QC', 'Soul Calibur - Sega Dreamcast', 5.0),
#  ('A3EMKG6C7AYIP7', 'Madden NFL 16 - PlayStation 4', 5.0),
#  ('A3VQWLFCQI6AK8', ' Nintendo  DSi  Bundle - Metallic Blue', 4.0),
#  ('A2O8CFNQDW91PL',
#   'Xbox 360 Ear Force XP500 Programmable Wireless Headset',
#   5.0),
#  ('A3LBMNX6N6C2CW', 'Sonic Adventure 2 Battle - GameCube', 5.0),
#  ('A3E75HFDI535U3', 'Pokemon X', 5.0),
#  ('A117GJYXI844FX', 'Dragon Age Inquisition - Deluxe Edition - PC', 2.0),
#  ('A31J8B1CLUXSJT', 'Shape Up - Xbox One', 3.0),
#  ('A1HGMA4Z8V1LI1',
#   'MAG II Wireless Induction Controller for PS3 and PC',
#   5.0),
#  ('A12WWV3ENTRNA6', 'Lowpricenice Headset with Microphone for Xbox 360', 5.0),
#  ('A1Q0YQMU9NHAR6',
#   'Logitech G502 Proteus Spectrum RGB Tunable Gaming Mouse, 12,000 DPI On-The-Fly DPI Shifting, Personalized Weight and Balance Tuning with (5) 3.6g Weights, 11 Programmable Buttons',
#   5.0),
#  ('AYNAI33HUMALW', 'Tales of Symphonia - Gamecube', 4.0),
#  ('A3D196X2JVE5SY', 'John Deere: Drive Green - PC', 2.0),
#  ('AIDGTX55Y0OZ6', 'The Walking Dead Season 2 [Download]', 1.0),
#  ('AXI1BQE3ES3T',
#   'Empire and Napoleon Total War Collection - Game of the Year (PC DVD) [UK IMPORT]',
#   5.0),
#  ('A2ZWTKSL8PSPBJ',
#   'Skylanders Trap Team Holiday Bundle Pack - Xbox 360',
#   3.0),
#  ('A1NPBKI87DVDBT',
#   'Xim 4 Keyboard and Mouse Adapter for PS4, Xbox One, 360, PS3',
#   5.0),
#  ('A1B2Y26A5D0KSP', 'Super TC2000 Racing [Download]', 1.0),
#  ('A3FK9Y3VAEUOST',
#   'Abstract 02 Blue - Decal Style Skin fits original PS4 Gaming Console',
#   5.0),
#  ('A3RVPB52P7OM4D', 'Guitar Hero: On Tour', 3.0),
#  ('AQIF4I7PI34X3', 'The Legend of Dragoon - Playstation', 5.0),
#  ('AROFJMBS2O1FG', 'Sonic and the Black Knight - Nintendo Wii', 5.0),
#  ('A1M7HET7ENB122', 'Resident Evil 6 - Playstation 3', 5.0),
#  ('A1WSGSLSHPI7TA', 'Fallout: New Vegas - Ultimate Edition', 5.0),
#  ('AR3E6ZHJ6I9M1', 'LEGO Star Wars III The Clone Wars - Xbox 360', 1.0),
#  ('A2R19M039I8CEG', 'Myth: The Fallen Lords - PC/Mac', 5.0),
#  ('A1VQ48HKN8BOWU',
#   'BENGOO G9000 Stereo Gaming Headset for PS4, PC, Xbox One Controller, Noise Cancelling Over Ear Headphones with Mic, LED Light, Bass Surround, Soft Memory Earmuffs for Laptop Mac Nintendo Switch Games',
#   5.0),
#  ('AKA1IXXXVRI7B', 'Oni', 5.0),
#  ('A3HG17OIF06ESJ', 'Mahjongg Platinum Deluxe Edition', 1.0),
#  ('A1QR1GRXXUJ5VQ', 'The Sims 2 - PC', 5.0),
#  ('A3714PC23K9SUB', 'Madden NFL 25 - PlayStation 4', 1.0),
#  ('AGZZW1JIW4KG9', 'Rising Sun Gold - PC', 2.0),
#  ('A3K6W8NERKFI3G', 'Metroid Prime', 5.0),
#  ('A1R5KQ5VM500X7',
#   'Mayflash Nintendo GameCube Controller Adapter for Wii/Wii U',
#   5.0),
#  ('A15276F9454AU5', 'Bejeweled 3 [Instant Access]', 1.0),
#  ('A1QA0FTTA4LPIP', 'Tales of Xillia - Playstation 3', 5.0),
#  ('A2FH43B503KYBI', 'Call of Duty: Modern Warfare 3 - Xbox 360', 1.0),
#  ('A2VHHJKO61UUN6', 'Sony PlayStation Eye Camera (Bulk Packaging)', 5.0),
#  ('A3U0SU4X6ORJ7U', 'Super Smash Bros. - Nintendo 3DS', 5.0),
#  ('A2U65Q9MATLAF1', 'Burnout 2: Point of Impact - PlayStation2', 5.0),
#  ('A39WL80FAEJFTN',
#   'Dance Dance Revolution SuperNova 2 Bundle (includes Dance Mat) - PlayStation 2',
#   5.0),
#  ('AOI4YX8NSTJ9N',
#   'Grand Theft Auto: Episodes from Liberty City [Download]',
#   1.0),
#  ('A1MZZGQXMP0Y8M', 'Cinch Bag: Michonne', 5.0),
#  ('A16V1TLB9WY4M0', 'Nancy Drew: Danger by Design - PC', 1.0),
#  ('A1ASSREUR83PSD', 'Mario &amp; Sonic at the Olympic Games for wii', 5.0),
#  ('A1981KGW9BJUA4', 'SimCity: Limited Edition', 4.0),
#  ('A1BLKYIE149OVY', 'GameShark Pro', 1.0),
#  ('A12GQ17OIT2GJZ', 'PlayStation Vita - Wifi', 5.0),
#  ('ADN4XBZID3J1B', 'Microsoft Xbox 360 Wireless Receiver for Windows', 1.0),
#  ('A1398GO43HEPR1', 'Rollercoaster Tycoon 3 - PC', 5.0),
#  ('A13UX3ONE34JJK', 'Afterglow AX.1 Controller for Xbox 360 - Red', 2.0),
#  ('A2Q7BW6NLQBDC8',
#   'Mass Effect Andromeda - Pre-load - PS4 Digital Code',
#   3.0),
#  ('A2JCQ9CJ597E7X',
#   'Xploder Cheat System BRAND NEW for Nintendo Game Boy Advance SP GBA SP',
#   5.0),
#  ('A1B97EJXJ3NBI8', 'Nintendo Game Boy Advance SP - Platinum', 1.0),
#  ('A3IS0RTEGMYIF7', 'Rayman Legends Xbox One Standard Edition', 5.0),
#  ('A39MWE5OXGG127', 'NCAA Football 2003', 5.0),
#  ('A1J1ZD5C2PKFPV', "Udraw: Dood's Big Adventure", 3.0),
#  ('A2O3IYM0G9YK9P',
#   'LittleBigPlanet - Game of the Year Edition Playstation 3',
#   5.0),
#  ('A32VHRNMFN6AGI', 'Battlefield 4 - Playstation 3', 3.0),
#  ('A1MHB1HRR6VPEH', 'Knack (PlayStation 4)', 5.0),
#  ('A2OC23DIG7E4K7',
#   'G.SKILL RIPJAWS KM780 MX On-the-Fly Macro Mechanical Gaming Keyboard, Cherry MX Brown',
#   1.0),
#  ('A2LYVVPZ7Z3XPR',
#   'SADES SA807 Multi-Platform Stereo Professional Gaming Headset Over Ear Headphones with Microphone Volume-Control for PS4 Xbox One PC Mac Tablets Ipad Ipod Android(Black &amp; Blue)',
#   1.0),
#  ('AU6V2ZANBT06M', 'Kingdoms of Amalur: Reckoning - PS3 [Digital Code]', 5.0),
#  ('A1NBER3G3SDA5I', 'Bujingai: The Forsaken City', 5.0),
#  ('A2RBCQ0VKB32SN',
#   'Rock Band 4 Wireless Fender Stratocaster Guitar Controller for PlayStation 4 - Black',
#   5.0),
#  ('A5PF1C2D8IKV6', 'Tales of the Abyss - PlayStation 2', 5.0),
#  ('A176PHM96SVG3A', 'Battlefield 3 [Download]', 5.0),
#  ('AWELRM2HGJGZL',
#   'Kingdom Hearts HD 2.8 Final Chapter Prologue - PlayStation 4',
#   5.0),
#  ('A3VG46LOJH4WUC', 'The Longest Journey - PC', 5.0),
#  ('A24MU98Z5J2C4P',
#   'Logitech G900 Chaos Spectrum Professional Grade Wired/Wireless Gaming Mouse, Ambidextrous Mouse',
#   2.0),
#  ('AAPUTV73KHI26', 'Sonic Riders: Zero Gravity - PlayStation 2', 3.0),
#  ('A3JHCTFOK9MEQY',
#   'SteelSeries Heroes of the Storm Gaming Mouse (Certified Refurbished)',
#   5.0),
#  ('A2SDM8S2SBHTQR',
#   'Nintendo Selects: The Legend of Zelda: Ocarina of Time - 3DS [Digital Code]',
#   4.0),
#  ('A1FGNEY3P4UT5N', 'Halo - Xbox', 5.0),
#  ('AUZF6JFWU6LLS', 'Hyrule Warriors - Nintendo Wii U', 1.0),
#  ('A3FEX334DNWVFW', 'amiibo squid [Orange]', 5.0),
#  ('A2CKJ78CZDJ9CS',
#   'Designer Skin for Playstation 3 Remote Controller - Weeds Black',
#   5.0),
#  ('A18SK68D585J67', 'Grand Theft Auto V - Xbox One', 5.0),
#  ('A3QZ3U06VKYQTT', 'Grand Theft Auto V - PlayStation 4', 5.0),
#  ('A2P1HKNT6ZZL42',
#   'Playstation Plus: 3 Month Membership [Digital Code]',
#   5.0),
#  ('A1EPWQ466UCZAA', 'Rock Candy Blueberry Boom', 2.0),
#  ('A2B55FG9UQJV25',
#   'Fosmon [Set of 4] Analog Stick Joystick Controller Performance Thumb Grips for PS4 | PS3 | Xbox One | Xbox 360 | Wii U (Black &amp; Blue)',
#   5.0),
#  ('A1GUG6OSZNOT6R', 'Dead Space 3 Limited Edition', 5.0),
#  ('A2R8Z43V93Y10O', 'Mafia III - PlayStation 4', 2.0),
#  ('A1WLHNY7RNKEJL', 'New Super Mario Bros. Wii', 5.0),
#  ('A3UALWDMM9SNSH', 'Dragonheart: Fire &amp; Steel (Sega Saturn, 1996)', 5.0),
#  ('A2152SKTHWAUAV', 'The Legend of Zelda: Skyward Sword with Music CD', 5.0),
#  ('A91Q01AGKGYMX',
#   'PS4 Controller Charger, Y Team Playstation 4 / PS4 / PS4 Pro / PS4 Slim Controller Charger Charging Docking Station Stand.Dual USB Fast Charging Station &amp; LED Indicator for Sony PS4 Controller--Black',
#   1.0),
#  ('A1CNV4MVHQOQLR', 'FIFA 15 - PlayStation 3', 5.0),
#  ('A3Q8YLN407H58W', 'Ideazon Merc Stealth Illuminated Gaming Keyboard', 5.0),
#  ('A2NISDCJOUE6V3', 'Mystical Ninja Starring Goemon', 5.0),
#  ('A1UNV7XHOLBZ7T',
#   'HORI Screen Protective Filter for Nintendo NEW 3DS XL',
#   5.0),
#  ('A2582IC8A72X3', 'Lara Croft Tomb Raider: The Angel of Darkness', 3.0),
#  ('A3V4YV2Q8C8OBL',
#   'SADES SA708 3.5mm Stereo Gaming Headset Headset with Microphone (Green)',
#   1.0),
#  ('A13WSYON9MWMSW', 'Xbox 360 Black Play and Charge Kit', 1.0),
#  ('A10RSHM2CIMWR2', 'Gameboy Color AC Adapter', 1.0),
#  ('AFEJD8B9CH7H4', 'The Sims 2 Nightlife Expansion Pack - Mac', 5.0),
#  ('A1IJAHT66Y6VXZ', 'Batman: Dark Tomorrow', 1.0),
#  ('A1CGETNFML63WX', 'True Crime: Streets of LA - Xbox', 5.0),
#  ('A1XWWGOHPAEH2R', 'Over G Fighters (Xbox 360)', 4.0),
#  ('A32H58XBRRV01H', 'Destiny - Standard Edition - Xbox One', 5.0),
#  ('A1NGBMYR6ZO119', 'Mad Catz Arcade FightStick PRO for PlayStation 3', 5.0),
#  ('A3152HI9445BRK', 'Dark Cloud 2 - PlayStation 2', 5.0),
#  ('A1XXH7CZNSVGRZ', 'MAYFLASH N64 Controller Adapter For Pc', 4.0),
#  ('A3C8KDSL8F4A80',
#   'New Interchangeable Power Charging Adapter &amp; Cable for Nintendo Wii U GamePad',
#   5.0),
#  ('A2XSOD2M0V6OXU', 'Street Fighter Anniversary Collection', 5.0),
#  ('A1KFMRI6G3DD0S',
#   "Assassin's Creed: Syndicate - Standard Edition - PlayStation 4",
#   4.0),
#  ('AE9KIF1FDCPJD',
#   'Xbox One Controller Rechargeable Battery Pack w/ USB Charging Cable, Play While You Charge Power Kit',
#   1.0),
#  ('A2EE6KVZU55OM7', 'Monster Hunter 4 3DS LL Pouch (emblem)', 5.0),
#  ('A1QMP2MIY4OK3X', 'Resident Evil 2', 5.0),
#  ('A1ENNKQ5MKYG1O', 'Michael Jackson The Experience - Nintendo Wii', 5.0),
#  ('AY5Y6A177S6FO', 'Need for Speed Most Wanted - Xbox 360', 5.0),
#  ('AKIQR1QKAFQAX', 'Pok&eacute;mon Omega Ruby - Nintendo 3DS', 5.0),
#  ('A1HSTM7CCT7JJK', 'Battlefield Hardline - PlayStation 4', 4.0),
#  ('A1WHH1X5CG3V4F', 'Dance Dance Revolution DDR Max - PlayStation 2', 4.0),
#  ('A18SRCHA6M3OQK', 'Gallop Racer', 4.0),
#  ('A1NLMVUYL339TO', 'Call of Duty: Modern Warfare 3 - Xbox 360', 5.0),
#  ('A2F24XX2MQ6IW4', 'Mortal Kombat X (PC DVD)', 5.0),
#  ('A3NMGZ01TF8M65', 'Xbox 360 Wireless Controller - Glossy Black', 5.0),
#  ('A3V30PMLRN9GNH', 'Pokken Tournament - Wii U', 5.0),
#  ('A20PGJETN0WIFI', 'Aliens: Colonial Marines - Xbox 360', 4.0),
#  ('A172B4CV3VS28S', 'Diablo III: Ultimate Evil Edition', 5.0),
#  ('ARC0IVB23WUBE', 'Lego Star Wars: The Complete Saga - Xbox 360', 5.0),
#  ('A34AY9GZX7F42U', ' Star Wars', 4.0),
#  ('A1V7QVIA1ERN8A',
#   'Command and Conquer The Ultimate Collection [Online Game Code]',
#   1.0),
#  ('A2LYAJJQDE5DNK', 'Batman: Arkham Origins - Playstation 3', 4.0),
#  ('A3OXO567LQ2JQU',
#   'ROCCAT ROC-11-810 KONE XTD - Max Customization Gaming Mouse',
#   2.0),
#  ('A3Q1SFHBSKVU6L',
#   'LEGO Jurassic World - PlayStation 4 Standard Edition',
#   3.0),
#  ('ATKLVVRBNM75Y', 'Sorry - PC', 2.0),
#  ('AZ9C61ABFQXM0', 'Pro Evolution Soccer 2015 - PlayStation 3', 5.0),
#  ('A2Y5EB66890P39', 'Dungeon Siege - PC', 5.0),
#  ('A27C4XT7SKMA2D', 'The Sims 3 Starter Pack (Mac) [Online Game Code]', 5.0),
#  ('AVH3H1NZ5W83X', 'Nyko Pure HD HDMI Cable - Playstation 3', 5.0),
#  ('A2P33GKMZIC9YO', 'Xbox One Stereo Headset Adapter', 4.0),
#  ('A2HUPXZKDRXFPU',
# ...
#  ('A2JVOO63C16ITX', 'KontrolFreek FPS Freek CQC Signature - Xbox One', 5.0),
#  ('AYJIIGDCM61VU',
#   'HyperX Cloud Revolver Gaming Headset for PC &amp; PS4 (HX-HSCR-BK/NA)',
#   4.0),
#  ('A208Z927V0SEIX',
#   'TRENDnet Wireless N Gaming Adapter TEW-647GA (Black)',
#   4.0),
#  ('AXGJNBYPUNR2',
#   'Carry Case for Nintendo New 2DS XL/New 3DS XL, Keten Hard Travel Protective Shell for New Nintendo 3DS, New 2DS Console&amp;Game, Also for Anker External Battery Store',
#   4.0),
#  ('A2AET7GYEKV7RP', 'Star Wars: The Force Unleashed II - PC', 4.0),
#  ('A29G9SCDF44I7N',
#   'CorpCo 6ft AC Power Cord for Sony PlayStation 4 (PS4)',
#   5.0),
#  ('A1798SYP2E2KY1',
#   'Tom Clancy&rsquo;s Ghost Recon Wildlands - PlayStation 4',
#   5.0),
#  ('AJWQTW4JII9DL',
#   'Nyko Modular Charge Station (New Version) Dual Port Controller Charging Station with Patented Charging Dongles for All PS4 , PS4 Slim and PS4 Pro',
#   3.0),
#  ('A2XAGH6UISHD5L', 'Watch Dogs 2 - Xbox One', 5.0),
#  ('A374QZE54RMC7W',
#   'Havit Gaming Mouse, 2800DPI 6 Buttons LED Optical Wired Mouse, Black',
#   1.0),
#  ('AMEUONVX9F0AL',
#   'CM Storm QuickFire Rapid-i Fully Backlit Mechanical Gaming Keyboard with ActivLite Technology and Per-Key Lighting (Brown Switch Model)',
#   5.0),
#  ('A1JHJSUC2P25IL', "Assassin's Creed Rogue- PlayStation 3", 3.0),
#  ('A3MP7312U2AP8L',
#   'CRS Hot Dragonpad&reg;accessory-experts Rumble Wireless Bluetooth Controller Gamepads Remotes for the Sony Playstation 3 in Red',
#   5.0),
#  ('AOJ1G79WH5U15', 'PlayStation 2 Vertical Console Stand', 1.0),
#  ('A3UULZW3IAHLLD', "Asheron's Call 2: Fallen Kings - PC", 5.0),
#  ('A1FTF8NHRU9LU6', 'Komodo Playstation 1 Memory Card 1MB', 5.0),
#  ('A2WLPBIWBYHQEJ', 'Mario Kart 8 - Nintendo Wii U', 5.0),
#  ('A1BOCXNLU8TAT9',
#   'Fallout 3 Game Add-On Pack: Broken Steel and Point Lookout',
#   5.0),
#  ('A38NMETU1NAH14', '4x Wii/Gamecube Extension Cables', 5.0),
#  ('A10AQPJKHBR30U', 'Mass Effect - Xbox 360', 5.0),
#  ('A2N5G4APZEISQM', 'The Sims 3 Dragon Valley - PC/Mac', 3.0),
#  ('A2Q7JAFPUNJA62',
#   'Avantree Long Range Bluetooth USB Adapter for Headphones, Speakers, Driver-Free Wireless Audio Dongle Transmitter, Plug-n-Play, aptX Low Latency, for PC Mac PS4 Nintendo Switch Linux [24M Warranty]',
#   5.0),
#  ('A2J096BEL0LHS9', 'Wallace and Gromit in Project Zoo', 5.0),
#  ('AOUYS72MB141D', 'Crysis 3 - PC', 4.0),
#  ('A3JI6GVQ86GXSA', 'Adventures of TinTin - Playstation 3', 4.0),
#  ('A2FRY84P4VM7B5', 'Dishonored - PC', 5.0),
#  ('A1PBRAUZOKA93W',
#   'Call Of Duty: Infinite Warfare - Legacy Edition - PS4 [Digital Code]',
#   1.0),
#  ('A37A9ZSL5PTRKY',
#   ' Repair Replacement - LCD Touch Screen Part for NDSL Nintendo DS Lite',
#   5.0),
#  ('A229YSU4ULUHUP', 'Rocksmith 2014 Edition - PC/Mac (Cable Included)', 5.0),
#  ('A3P0062WG6Z1H2',
#   "Baldur's Gate 2: Ultimate Collection (Shadows of Amn and Throne of Bhaal) - PC",
#   5.0),
#  ('A3TMG1GVRXZRB3', 'Guitar Hero: Van Halen', 5.0),
#  ('A3R5LOGIJO1Z6O',
#   'Corsair Vengeance 2100 Wireless Dolby 7.1 Gaming Headset (V2100)',
#   5.0),
#  ('A29BQ6B90Y1R5F', 'Luminous Arc 2 - Nintendo DS', 4.0),
#  ('A2MCIY5PKU3T3M',
#   'Fosmon Component HD AV Cable to HDTV/EDTV (High Definition 480p) for Nintendo Wii &amp; Wii U',
#   5.0),
#  ('A136T75MX8PQ3Q',
#   'EXSEK EZFlash Omega Cartridge flash cart for gameboy advance GBA SP',
#   5.0),
#  ('A16NYY1D2RBOLK',
#   'Official Microsoft Xbox One USB Charging Cable (Bulk Packaging)',
#   2.0),
#  ('A2DGSWAKU0VB4P', 'The Legend of Zelda: The Wind Waker', 5.0),
#  ('A36UIGVTB9NREK',
#   'Logitech G910 Orion Spark RGB Mechanical Gaming Keyboard &ndash; 9 Programmable Buttons, Dedicated Media Controls',
#   5.0),
#  ('A3UM7Q1KO1228S',
#   "Dell Professional P170S 17' LCD Monitor - 5:4 - 5 ms. 17IN LCD 1280X1024 800:1 P170S VGA/DVI HGT/SWIVEL/TILT/USB BLK LCD. Adjustable Display Angle - 1280 x 1024 - 16.7 Million Colors - 250 Nit - 800:1 - DVI - VGA - Energy Star, EPEAT Gold",
#   2.0),
#  ('ALFYCDCO342DS',
#   'Xbox One Controller Keyboard - 2.4Ghz Wireless Mini Bluetooth Text Messenger Chatpad Keypad Adapter for Xbox One Game Controller Black [Xbox One]',
#   5.0),
#  ('AKR64MCFI9G9C', 'Castlevania: Circle of the Moon', 5.0),
#  ('A3O11VQGRD0X24', 'Wii', 5.0),
#  ('A1B7V73GW4YUGR',
#   'dreamGEAR- Playstation 4 Charge and Play Premium Connection Cable- Perfect for Charging DualShock4 Controllers',
#   5.0),
#  ('A16WICOGGND5FN',
#   'BenQ ZOWIE FK1 E-Sports Ambidextrous Optical Gaming Mouse',
#   5.0),
#  ('A2C747CS6U3Z12', 'F-1 Pole Position', 1.0),
#  ('A1W3CP35QZPU8',
#   'GelTabz Performance Thumb Grips - PlayStation 4 and PlayStation 3',
#   4.0),
#  ('A4CSL56EJV9ZJ', 'The Walking Dead: Season 2 - PlayStation 3', 5.0),
#  ('A31GVQQQOX0056',
#   'Dungeons &amp; Dragons Online: StormReach - PC (Standard (DVD))',
#   1.0),
#  ('A1HW4A1U74CL6T', 'Ultimate Marvel vs Capcom 3 - PlayStation Vita', 4.0),
#  ('A1Y727XP8WQ8NS', 'Call of Duty: Ghosts - PlayStation 4', 5.0),
#  ('A3MXHUQEE21UU7',
#   'Monopoly Family Fun Pack - PlayStation 4 Standard Edition',
#   5.0),
#  ('A1UY63D46K7ODP', 'Kingdom Hearts', 5.0),
#  ('A23N7NU608P0K9',
#   'Anrain Dual PS4/PS4 Slim/PS4 Pro Gaming Controller LED Charging Stand USB Charger Dock Station Cradle For Sony Playstation 4 PS4 / PS4 Slim /PS4 Pro',
#   5.0),
#  ('A28T4N3QJPQBXM', 'Dead Space 3 Limited Edition', 3.0),
#  ('AVMP5N3NMO3WT',
#   'Nintendo Animal Crossing Happy Home Designer Amiibo Card Freya 196/200 USA Version',
#   5.0),
#  ('AVC65SGZ7CT5', 'NCAA Football 2005', 3.0),
#  ('A1RWYYXLLISGFN', "Overwatch - Collector's Edition - PC", 4.0),
#  ('A2KVBM7SVYNGB',
#   "Razer DeathAdder Chroma - Multi-Color Ergonomic Gaming Mouse - 10,000 DPI Sensor - Comfortable Grip - World's Most Popular Gaming Mouse",
#   2.0),
#  ('A1J04ESKVCM3WA',
#   'Minecraft: Story Mode - A Telltale Game Series - Season Disc (Xbox 360)',
#   5.0),
#  ('A1A3XLBRYAG93R', 'Battlefield 3: Premium Edition [Online Game Code]', 3.0),
#  ('A3QOLYK8ES5UD', 'Super Mario Bros. / Duck Hunt', 5.0),
#  ('A3L5TUOWWRBVP4',
#   'Playstation Plus: 3 Month Membership [Digital Code]',
#   1.0),
#  ('A3I1M37O37S8VA',
#   "Disney Infinity 3.0 Edition: Disney Pixar's Fear Figure",
#   5.0),
#  ('AJ8TUM7JRYCXK',
#   'GameSir G3f 2.4GHz Wireless Gamepad Controller for Android TV BOX PS3 &amp; PC(XP/7/8/8.1/10) - PS3',
#   1.0),
#  ('A1TSKEBDA5E7HH', 'Paper Mario: Color Splash - Wii U Standard Edition', 5.0),
#  ('A1VA2ZTA8YT5H8', 'The Sims 3: Pets - Playstation 3', 4.0),
#  ('A1QIHNZHUHQV08', 'Sudoku Gridmaster - Nintendo DS', 1.0),
#  ('A3T1NGR56F6OAB',
#   'Generic AC Power Adapter Charger for Nintendo 3DS/DSi/XL',
#   5.0),
#  ('A5FS50VW0GWEE', 'Sega Dreamcast Console', 4.0),
#  ('A38URFNMDZIFQ6', 'Silent Hunter: Wolves of the Pacific - PC', 1.0),
#  ('A6I0UBAG63829', 'Far Cry 3', 5.0),
#  ('A20E9JCRLAZYTC',
#   'HyperX Cloud Gaming Headset for PC, Xbox One&sup1;, PS4, PS4 PRO, Xbox One S&sup1;, Nnintedo Switch (KHX-H3CL/WR) - Black',
#   5.0),
#  ('AF8E3LE7RSK1T',
#   '258stickers&reg; Playstation 4 Console Skin &amp; Remote Controllers Skin - Evangelion Pilot Girl',
#   5.0),
#  ('A1F3O43F4078D8', 'Rock Band 3 Wireless Keyboard for Xbox 360', 1.0),
#  ('A2S20I3KH12O7H',
#   'TAKECASE New 3DS XL and 2DS XL Carrying Case - Fits Wall Charger - Includes XL Stylus, 16 Game Storage, Hard Shell and Accessories Pocket (Dark Blue)',
#   5.0),
#  ('A3FLSJCJM7AQMT', 'DS Game Card Case 24 - Black', 4.0),
#  ('A16JY34IXJQAN6',
#   'Dragonpad Wired USB Controller (Black) for PC &amp; Xbox 360',
#   3.0),
#  ('A42FI94ZUCKLL', 'Nintendo DS Lite Polar White', 5.0),
#  ('AO8XZU4RCPOUY', 'Final Fantasy VII: Dirge of Cerberus', 5.0),
#  ('A3EOL7UTSZ6WPS',
#   'Lord of the Rings: Return of the King - PlayStation 2',
#   2.0),
#  ('A265B1IZE5RVG6', 'DSi XL Jumbo Touch Pen Set - Black/White/Wine Red', 5.0),
#  ('A1HXPVMZRB6BK8',
#   'SteelSeries Rival 100, Optical Gaming Mouse - Black',
#   5.0),
#  ('A2SJD4P6BKE78A', 'Civilization 3 Game of The Year Edition - PC', 5.0),
#  ('A1FT5O4D8S38N6', 'Persona 5 - SteelBook Edition - PlayStation 4', 5.0),
#  ('A39YO36UINKTSC',
#   'Xbox Live Gold 12 Month Subscription Card [Microsoft]',
#   5.0),
#  ('A1KZCLMSII79B2',
#   'Pink Custom Mod Kit for Xbox 360 Controller(t8 Screwdriver Abxy,guide,start, Back,thumbsticks, D-pad, Buttons, Triggers, Bumpers, Bottom Trim)',
#   4.0),
#  ('A24U91T6L530UN',
#   'SteelSeries Rival 300, Optical Gaming Mouse - Black',
#   5.0),
#  ('ARBA3PVDL118W', 'Shadow Tower (PlayStation)', 3.0),
#  ('A20OFX4FZM0CYE', 'NASCAR 2008 - Xbox 360 (Back to Back)', 1.0),
#  ('A2CIC2HY5REVTX', 'Halo - Xbox', 5.0),
#  ('A3NEGA9XBIKWCY', 'TurboCAD 15 Deluxe 2D/3D', 5.0),
#  ('AJJ5VZCIGPM2H',
#   "Razer DeathAdder Chroma - Multi-Color Ergonomic Gaming Mouse - 10,000 DPI Sensor - Comfortable Grip - World's Most Popular Gaming Mouse",
#   5.0),
#  ('A1IH6DGAU19G3N', ' Castlevania', 4.0),
#  ('A2E7RYSYMPROML', 'Little Racers STREET [Download]', 4.0),
#  ('A3H9WAGLW46MQS', 'SingStar Queen - Stand Alone - Playstation 3', 5.0),
#  ('A35HX4LZV6AIZF',
#   'SmaAcc Cooling Fan with Dual Charging Station for PS4 Controllers/DualShock 4 Controllers',
#   5.0),
#  ('A2E2RN093GJMKU', 'Burnout 2: Point of Impact - PlayStation2', 5.0),
#  ('A3JKAVH9VY158U',
#   'PDP Energizer 2X Controller Charging Station for PS4',
#   5.0),
#  ('A29EAS376WQNWI', 'Ace Combat 5: The Unsung War', 5.0),
#  ('AIRRG0HT06033', 'Grand Theft Auto: San Andreas - PlayStation 2', 4.0),
#  ('A2TFV7WXL417JJ', 'PlayStation 4 DualShock 4 Bundle [Discontinued]', 5.0),
#  ('A2DI7VVBFWGKJ3', 'ATV Offroad Fury 2 - PlayStation 2', 4.0),
#  ('A2BODN4N3AACBW', 'Shrek 2 - PlayStation 2', 4.0),
#  ('A2RZHV6GVQHEYB',
#   '120GB 120G Internal HDD Hard Drive Disk Disc for Xbox360 XBOX 360 S Slim Games',
#   5.0),
#  ('A35HJBYRMUH6U', 'Sonic Mega Collection Plus - Xbox', 5.0),
#  ('A3PSTS96CBVT7W', 'Heavenly Sword - Playstation 3', 5.0),
#  ('A2RO4GH63DXYQ0', 'Mob Enforcer - PC', 2.0),
#  ('A229YNRXOMRP29', 'Sleeping Dogs: Definitive Edition- PlayStation 4', 5.0),
#  ('A1J4OZEQIKM2E', 'Fallout: New Vegas - PC', 4.0),
#  ('A1BYS96KW3YGIB',
#   'Battery2go Li-ion Battery Pack Fits Ninetendo WUP-012, WUP-010, Wii U, Wii U Gamepad',
#   1.0),
#  ('A1POGPDJ9ZRBW8', 'Lollipop Chainsaw - Xbox 360', 4.0),
#  ('A167AHAS130UHI',
#   'J-Tech Digital Scroll Endurance Wired Mouse Ergonomic Vertical USB Mouse with Adjustable Sensitivity (600/1000/1600 DPI), Removable Palm Rest &amp; Thumb Buttons - Reduces Hand/Wrist Pain (Wired)',
#   4.0),
#  ('A1907IX4EX96JX', 'Sennheiser GAME ONE Gaming Headset - White', 5.0),
#  ('ABC0UOPQ4MWBM', 'Myst 10th Anniversary DVD Edition - PC/Mac', 3.0),
#  ('AIZU24GW0RESB', 'Guitar Hero Live - Xbox One', 5.0),
#  ('AX1FT9WAKP5UA', 'Dotop XBOX Controller for Microsoft XBOX Black', 1.0),
#  ('A1RPDRCW5VY0HV', 'Mad Catz R.A.T.7 Gaming Mouse for PC and Mac', 1.0),
#  ('A15N17M6GC8MGY', 'Left 4 Dead 2 - PC', 1.0),
#  ('A2J05ZV2IZWQW4', "Mass Effect 3 Collector's Edition - PC", 1.0),
#  ('A2ME3RPCCJH9XL', 'Xbox 360 Messenger Kit', 5.0),
#  ('AP95XS6DE8GQP', 'Nancy Drew: The Phantom of Venice - PC', 5.0),
#  ('A37AO20OXS51QA', 'Batman: Arkham Knight - Windows Standard Edition', 1.0),
#  ('A3MZ108BL36WRX',
#   'PS4 Controller Charger, Y Team Playstation 4 / PS4 / PS4 Pro / PS4 Slim Controller Charger Charging Docking Station Stand.Dual USB Fast Charging Station &amp; LED Indicator for Sony PS4 Controller--Black',
#   5.0),
#  ('A1GCE7SYD95LSF',
#   'DLAND LED colorful 9 Programmable Keys Macro Definition 2500 DPI USB Wired Gaming Game Mice Mouse with with Dland Large Mousepad Gaming Mouse Mice Pad Mat 300x230x3 mm (L x W x H)(Up to 6000DPI By CD Driver)',
#   3.0),
#  ('A1O0ZXXY8I5CZ7',
#   'Logitech G502 Proteus Core Tunable Gaming Mouse with Fully Customizable Surface, Weight and Balance Tuning',
#   5.0),
#  ('A2DGQ2HEDMH8A2',
#   "Command &amp; Conquer Red Alert 2 Expansion: Yuri's Revenge - PC",
#   5.0),
#  ('A8O9S68JC4LFI', 'Elder Scrolls Online: Tamriel Unlimited - Xbox One', 1.0),
#  ('A3SMT9E20QM7BS',
#   'SteelSeries Siberia v3 Prism Gaming Headset-Cool Grey',
#   5.0),
#  ('A2O362XMHX30MO',
#   'EDOTA 2.4G Professional Rechargeable Wireless Gaming Mouse Mice with 6 Button Adjustable DPI 800/1600/2400 for Gamer Mac PC Computer (black)',
#   5.0),
#  ('A33NPMRZ42D6XC', 'Battlefield 2 Modern Combat - Xbox', 5.0),
#  ('A2DTHCFQP1M01W', 'Star Wars Knights of the Old Republic - Xbox', 5.0),
#  ('A2X71C90MLNSWR', 'Vampire: The Masquerade - Redemption (Jewel Case)', 3.0),
#  ('AH5SLA1ERKEMV',
#   'Generic 120GB Internal Slim Hard Disk Drive for XBOX 360 Black',
#   1.0),
#  ('A2GEM4SDS4G9NQ', 'Super Mario Kart', 1.0),
#  ('A38A60JW32S81R', 'Quest 64', 4.0),
#  ('A3BJJ2QDFI6AIK', 'Deception IV: Blood Ties - PlayStation 3', 5.0),
#  ('A2FAUZ4PIHOO4J', 'PlayStation Portable (PSP) Value Pack', 5.0),
#  ('A2GI43A75633P2', 'Guilty Gear X: Advance Edition', 1.0),
#  ('A1XGFVQ4HPJ9P7', 'Wii Sports Resort', 5.0),
#  ('A1GIYMP2FUKA7Q', 'Halo: Combat Evolved Anniversary (UK)', 5.0),
#  ('A1SSIW2OCP0S0B', 'Lightning Returns: Final Fantasy XIII', 1.0),
#  ('A1UCN7JMXO9K4J', "Assassin's Creed III - PC", 5.0),
#  ('A3D4WPTWNPP4QR', 'RPG Maker 2', 4.0),
#  ('AUSL0M9QW2F07', 'ESPN MLS Extra Time 2002', 4.0),
#  ('A17GS84LB5J5Z1', 'Ninja Gaiden 3 - Xbox 360', 1.0),
#  ('A2VFJJ1YWY4U2P',
#   'Gaming Headset for PS4 PSP Xbox one, SENHAI Led Light GM-1 Headphone with Microphone and Free Adapter Cable (Black+Blue,With Original Package, Perfect for Gift)',
#   5.0),
#  ('A2D7JES80AF6TL', 'Enchanted Cavern [Download]', 5.0),
#  ('A3UFYTT4FBIUDC',
#   'PlayStation 4 500GB Console - Uncharted 4 Limited Edition Bundle [Discontinued]',
#   4.0),
#  ('A27GYMIQKLB8U8', 'Wii Rock Band Special Edition', 5.0),
#  ('A36POD6N9NIB3A',
#   'Charizard Special Edition Limited Video Game Vinyl Decal Skin Sticker Cover for the New Nintendo 3DS XL LL 2015 System Console',
#   5.0),
#  ('A1E421J0HD8O1Y',
#   'Logitech G602 Lag-Free Wireless Gaming Mouse &ndash; 11 Programmable Buttons, Up to 2500 DPI',
#   5.0),
#  ('A3EPEFDQ3JPLMN',
#   'Dragon Age Inquisition - Game of the Year Edition - PlayStation 4',
#   5.0),
#  ('A6D3DP3EGI9FL', 'Xbox Controller (Original Design)', 5.0),
#  ('AS212YDSPITZ0', 'Official Nintendo Wii Comfort Racing Wheel - Black', 4.0),
#  ('A13TO1ZFAH9SVN', 'Gamecube Memory Card 251', 5.0),
#  ('A3HW8CCS0YCFFM',
#   'PlayStation 3 Dualshock 3 Wireless Controller (Crimson Red)',
#   5.0),
#  ('A1M2K122N31FFB', 'Classic Pro Controller - Black (Wii)', 5.0),
#  ('A3MG6EEI53SVL0',
#   'Redragon M601 Wired Gaming Mouse, Ergonomic, Programmable 6 Buttons, 3200 DPI with Red LED Mouse for Windows PC Games - Black',
#   5.0),
#  ('A25WC2ARY33AWW', "Baldur's Gate II:  Shadows of Amn", 5.0),
#  ('ATFC94CX7I2BM', 'Super Smash Bros. - Nintendo 3DS', 5.0),
#  ('A33MOYL4Y24QE4', 'The Lord of the Rings: Mines of Moria - PC', 4.0),
#  ('A2BSQHPLQ2WR98', 'PlayStation Silver Wired Stereo Headset', 2.0),
#  ('A21ZJG309XM5R4', 'God of War III - Playstation 3', 3.0),
#  ('A71VTL49EODH9', 'ESPN X Games: Skateboarding', 3.0),
#  ('A369QGLXCPJU4C', 'NHL 08 - Playstation 3', 4.0),
#  ('A36LPT0H6DX2PT', 'Super Smash Bros Melee', 5.0),
#  ('A2GBBDNZLYC4A9', 'Half-Life 2 - PC', 5.0),
#  ('A1T1HRNMFI4ET3', 'Diablo III', 5.0),
#  ('A2JFEMPNQJJ69J',
#   'RetroBit Retro Adapter NES Controller to USB Port Adapter',
#   5.0),
#  ('A256MTBEX70NEO', 'Metroid Prime', 5.0),
#  ('A3KSMMXTRBG17N',
#   'Logitech G502 Proteus Spectrum RGB Tunable Gaming Mouse, 12,000 DPI On-The-Fly DPI Shifting, Personalized Weight and Balance Tuning with (5) 3.6g Weights, 11 Programmable Buttons',
#   5.0),
#  ('A13DMUPSEGJFQQ',
#   'BenQ Zowie ZA12 E-Sports Ambidextrous Optical Gaming Mouse',
#   5.0),
#  ('A1MYL0CDB0BW16',
#   'Corsair Vengeance M65 Performance FPS Gaming Mouse, Gunmetal Black (CH-9000022-NA)',
#   5.0),
#  ('A1BUIV8QE20MMR', 'Memorex Wireless Nunchuk-Black - Nintendo Wii', 5.0),
#  ('A3UI44VJHWSI1T', 'Torchlight', 3.0),
#  ('A3T7R5UWGNGLZU', 'NHL 17 - PlayStation 4', 5.0),
#  ('A2Z5OPKYL1ERJR',
#   'Vanknight Vinyl Decals Skin Sticker Anime for the New Nintendo 3DS XL 2015',
#   4.0),
#  ('A1H6FJ5585BOVS',
#   'ElementDigital&reg; Wireless Controller for Xbox 360, PS3, PC and Android Device Vibration Shock 2.4G Game Handle Gamepad Ergonomic White',
#   1.0),
#  ('A88KLRD6LE8NR', 'Drawn To Life: Spongebob Squarepants', 4.0),
#  ('A2UWUP3X73XEPT',
#   'COSMOS &reg; Light Blue Protection Hard Case Cover for Playstation PS VITA 1000, Fits for Oval Start &amp; Select Button Only, with LCD Touch Screen Cleaning Cloth',
#   5.0),
#  ('A2IXAC24UXZTJB', ' Animal Crossing', 5.0),
#  ...]

# %% [markdown]
# ## KNN Basic

# %%
KNN_model= knns.KNNBasic(sim_options={'name': 'cosine', 'user_based': False}).fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
cross_validate(KNN_model, data, verbose= True, n_jobs=-1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2967  1.3165  1.3062  1.3070  1.2987  1.3050  0.0070
# MAE (testset)     0.9703  0.9858  0.9748  0.9759  0.9743  0.9762  0.0051
# Fit time          56.14   57.66   56.20   53.79   53.85   55.53   1.50
# Test time         0.64    0.35    0.39    0.61    0.37    0.47    0.13
# {'test_rmse': array([1.29667705, 1.3164655 , 1.30615174, 1.3069601 , 1.29872379]),
#  'test_mae': array([0.97029964, 0.98580177, 0.97480664, 0.97591937, 0.9743212 ]),
#  'fit_time': (56.141650915145874,
#   57.65526604652405,
#   56.20202279090881,
#   53.78870487213135,
#   53.850388050079346),
#  'test_time': (0.6395540237426758,
#   0.34877920150756836,
#   0.38604021072387695,
#   0.6083400249481201,
#   0.3662452697753906)}

# %%
KNN_model2= knns.KNNBasic(sim_options={'name': 'msd', 'user_based': False}).fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
cross_validate(KNN_model2, data, verbose= True, n_jobs=-1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3070  1.2933  1.3055  1.2950  1.2943  1.2990  0.0060
# MAE (testset)     0.9739  0.9611  0.9742  0.9641  0.9623  0.9671  0.0057
# Fit time          55.81   55.55   55.80   55.31   55.03   55.50   0.30
# Test time         0.62    0.58    0.66    0.61    0.50    0.59    0.05
# {'test_rmse': array([1.30702091, 1.29331413, 1.30550743, 1.29498519, 1.29428809]),
#  'test_mae': array([0.97390054, 0.96114017, 0.97424211, 0.96405965, 0.9622922 ]),
#  'fit_time': (55.805038928985596,
#   55.55095672607422,
#   55.80167579650879,
#   55.30667281150818,
#   55.02721285820007),
#  'test_time': (0.6193728446960449,
#   0.5824072360992432,
#   0.6564249992370605,
#   0.6091680526733398,
#   0.5015571117401123)}

# %%
KNN_model3= knns.KNNBasic(sim_options={'name': 'pearson', 'user_based': False}).fit(trainset)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
cross_validate(KNN_model3, data, verbose= True, n_jobs=-1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3051  1.2931  1.3026  1.2888  1.2918  1.2963  0.0064
# MAE (testset)     0.9615  0.9541  0.9655  0.9541  0.9579  0.9587  0.0044
# Fit time          50.71   53.08   50.44   53.93   49.82   51.60   1.61
# Test time         0.59    0.34    0.52    0.28    0.54    0.45    0.12
# {'test_rmse': array([1.30506132, 1.29309865, 1.30259424, 1.28879011, 1.29182685]),
#  'test_mae': array([0.96154875, 0.95411434, 0.96553037, 0.95412569, 0.9579485 ]),
#  'fit_time': (50.708773136138916,
#   53.078081130981445,
#   50.44257378578186,
#   53.9336199760437,
#   49.816184759140015),
#  'test_time': (0.5917799472808838,
#   0.3407597541809082,
#   0.5162580013275146,
#   0.28071093559265137,
#   0.5371177196502686)}

# %%
KNN_model4= knns.KNNBasic(sim_options={'name': 'pearson_baseline', 'user_based': False}).fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
cross_validate(KNN_model4, data, verbose= True, n_jobs=-1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3024  1.2958  1.2967  1.2976  1.2975  1.2980  0.0023
# MAE (testset)     0.9649  0.9626  0.9582  0.9613  0.9596  0.9613  0.0023
# Fit time          49.75   51.10   50.25   50.21   50.10   50.28   0.44
# Test time         0.53    0.50    0.39    0.48    0.45    0.47    0.05
# {'test_rmse': array([1.30237473, 1.29577235, 1.29667927, 1.29759325, 1.29745356]),
#  'test_mae': array([0.96488078, 0.96259135, 0.95820719, 0.96128778, 0.95964681]),
#  'fit_time': (49.753724813461304,
#   51.09508514404297,
#   50.25413107872009,
#   50.213900089263916,
#   50.098995208740234),
#  'test_time': (0.5322749614715576,
#   0.49553728103637695,
#   0.3861398696899414,
#   0.4799790382385254,
#   0.45453691482543945)}

# %% [markdown]
# ## KNN With Means

# %%
KNN_model= knns.KNNWithMeans(sim_options={'name': 'cosine', 'user_based': False}).fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
cross_validate(KNN_model, data, verbose= True, n_jobs=-1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3145  1.3162  1.3036  1.3027  1.3096  1.3093  0.0055
# MAE (testset)     0.9768  0.9782  0.9682  0.9685  0.9714  0.9726  0.0042
# Fit time          47.81   48.31   48.48   47.62   47.04   47.85   0.51
# Test time         0.72    0.47    0.31    0.33    0.35    0.43    0.15
# {'test_rmse': array([1.31445833, 1.31624245, 1.30363781, 1.30273256, 1.3096166 ]),
#  'test_mae': array([0.97683726, 0.97820841, 0.96823514, 0.96850464, 0.97138305]),
#  'fit_time': (47.81424903869629,
#   48.30622100830078,
#   48.47829604148865,
#   47.615411043167114,
#   47.041229009628296),
#  'test_time': (0.716500997543335,
#   0.46961116790771484,
#   0.30996012687683105,
#   0.3289520740509033,
#   0.34900879859924316)}

# %%
KNN_model2= knns.KNNWithMeans(sim_options={'name': 'msd', 'user_based': False}).fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
cross_validate(KNN_model2, data, verbose= True, n_jobs=-1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2996  1.3020  1.3097  1.3040  1.3070  1.3044  0.0036
# MAE (testset)     0.9605  0.9601  0.9692  0.9675  0.9674  0.9650  0.0038
# Fit time          60.95   61.51   61.69   60.84   60.60   61.12   0.41
# Test time         0.72    0.64    0.49    0.43    0.44    0.54    0.11
# {'test_rmse': array([1.29959384, 1.30200683, 1.30969295, 1.3039749 , 1.30696601]),
#  'test_mae': array([0.96051324, 0.96014564, 0.96915187, 0.96753465, 0.96743836]),
#  'fit_time': (60.95057988166809,
#   61.51298928260803,
#   61.68616318702698,
#   60.83865475654602,
#   60.598276138305664),
#  'test_time': (0.7162270545959473,
#   0.6378788948059082,
#   0.49219298362731934,
#   0.434877872467041,
#   0.4386141300201416)}

# %%
KNN_model3= knns.KNNWithMeans(sim_options={'name': 'pearson', 'user_based': False}).fit(trainset)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
cross_validate(KNN_model3, data, verbose= True, n_jobs=-1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3006  1.2987  1.3009  1.3052  1.3059  1.3023  0.0028
# MAE (testset)     0.9559  0.9537  0.9566  0.9627  0.9618  0.9581  0.0035
# Fit time          60.51   60.83   58.53   60.28   58.92   59.81   0.91
# Test time         0.43    0.44    0.74    0.31    0.33    0.45    0.15
# {'test_rmse': array([1.30062477, 1.29869273, 1.3008936 , 1.3052147 , 1.3059231 ]),
#  'test_mae': array([0.95592434, 0.95368688, 0.95656881, 0.96271495, 0.96178389]),
#  'fit_time': (60.5059609413147,
#   60.82538604736328,
#   58.5308837890625,
#   60.27626395225525,
#   58.915345907211304),
#  'test_time': (0.42750096321105957,
#   0.44039320945739746,
#   0.7377080917358398,
#   0.30954909324645996,
#   0.3265848159790039)}

# %%
KNN_model4= knns.KNNWithMeans(sim_options={'name': 'pearson_baseline', 'user_based': False}).fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
cross_validate(KNN_model4, data, verbose= True, n_jobs=-1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3056  1.2993  1.3002  1.3037  1.3092  1.3036  0.0036
# MAE (testset)     0.9657  0.9563  0.9542  0.9612  0.9624  0.9600  0.0042
# Fit time          64.94   68.00   67.20   66.59   65.86   66.52   1.06
# Test time         0.87    0.41    0.41    0.40    0.47    0.51    0.18
# {'test_rmse': array([1.30561396, 1.29928417, 1.3002484 , 1.30365682, 1.3091943 ]),
#  'test_mae': array([0.96572902, 0.95633506, 0.9541786 , 0.96123706, 0.96241009]),
#  'fit_time': (64.94071006774902,
#   68.00457620620728,
#   67.20421576499939,
#   66.59040379524231,
#   65.85597372055054),
#  'test_time': (0.865253210067749,
#   0.41051506996154785,
#   0.407520055770874,
#   0.3995490074157715,
#   0.4683661460876465)}

# %% [markdown]
# ## SVD

# %%
svd = SVD()

# %%
svd.fit(trainset)

# %%
predictions= svd.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 1.2324
# 1.2324324052459386

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.9516
# 0.9515967603715499

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created?
# * How did you address missing values or outliers?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
# Here you run your code to clean the data

# %% [markdown]
# ## Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
# Here you run your code to model the data

# %% [markdown]
# ## Evaluation
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# ## Conclusions
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***
